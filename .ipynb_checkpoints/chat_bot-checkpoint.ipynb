# %% [markdown]
# # Load the Dataset

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\boeylee\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: filelock in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (2.32.2)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\boeylee\anaconda3\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\boeylee\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\boeylee\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\boeylee\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\boeylee\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\boeylee\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\boeylee\anaconda3\lib\site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\boeylee\anaconda3\lib\site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\boeylee\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\boeylee\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\boeylee\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\boeylee\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\boeylee\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\boeylee\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\boeylee\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\boeylee\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\boeylee\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in c:\users\boeylee\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\boeylee\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\boeylee\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\boeylee\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\boeylee\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\boeylee\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Extract Questions and Labels

# %%
from datasets import load_dataset

# Load the dataset
ds = load_dataset("bitext/Bitext-customer-support-llm-chatbot-training-dataset")

# Preview the dataset
print(ds['train'][0])  # Print the first sample
# Out:
# {'flags': 'B', 'instruction': 'question about cancelling order {{Order Number}}', 'category': 'ORDER', 'intent': 'cancel_order', 'response': "I've understood you have a question regarding canceling order {{Order Number}}, and I'm here to provide you with the information you need. Please go ahead and ask your question, and I'll do my best to assist you."}

# %%
#Extract 'question', 'label', and 'response' fields from the dataset
labeled_data = [{'question': item['instruction'], 'label': item['intent'], 'response': item['response']} for item in ds['train']]

# Preview the labeled data
print(labeled_data[:5])  # Print the first 5 records
# Out:
# [{'question': 'question about cancelling order {{Order Number}}', 'label': 'cancel_order', 'response': "I've understood you have a question regarding canceling order {{Order Number}}, and I'm here to provide you with the information you need. Please go ahead and ask your question, and I'll do my best to assist you."}, {'question': 'i have a question about cancelling oorder {{Order Number}}', 'label': 'cancel_order', 'response': "I've been informed that you have a question about canceling order {{Order Number}}. I'm here to assist you! Please go ahead and let me know what specific question you have, and I'll provide you with all the information and guidance you need. Your satisfaction is my top priority."}, {'question': 'i need help cancelling puchase {{Order Number}}', 'label': 'cancel_order', 'response': "I can sense that you're seeking assistance with canceling your purchase with the purchase number {{Order Number}}. I apologize for any inconvenience caused, and I'm here to guide you through the process.\n\nTo cancel your purchase, please follow these steps:\n\n1. Log into your account: Visit our {{Online Company Portal Info}} and sign in using your credentials.\n2. Locate your order: Once logged in, navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction}}' section to find the purchase with the order number {{Order Number}}.\n3. Initiate the cancellation: Upon finding your purchase, look for the option labeled '{{Online Order Interaction}}' and click on it to initiate the cancellation process.\n4. Confirm the cancellation: Our system might ask for confirmation or feedback regarding the cancellation. Kindly provide the necessary information to complete the process.\n5. Seek additional support: If you encounter any difficulties or require further assistance, our dedicated customer support team is available during {{Customer Support Hours}}. You can contact us at {{Customer Support Phone Number}} or use the Live Chat feature on our {{Website URL}}.\n\nWe appreciate your understanding and value your satisfaction. Should you have any more questions or concerns, feel free to reach out to us. We're here to help you."}, {'question': 'I need to cancel purchase {{Order Number}}', 'label': 'cancel_order', 'response': 'I understood that you need assistance with canceling your purchase with the order number {{Order Number}}. We apologize for any inconvenience this may have caused. To initiate the cancellation process, please follow these steps:\n\n1. Sign in to your account: Visit our {{Online Company Portal Info}} and login using your credentials.\n2. Access your order history: Once logged in, navigate to the "{{Online Order Interaction}}" or "{{Online Order Interaction}}" section.\n3. Locate the purchase: Look for the order with the specific order number {{Order Number}}.\n4. Cancel the purchase: Click on the "{{Online Order Interaction}}" option associated with the purchase.\n5. Confirm the cancellation: Follow any further prompts or questions from the system to finalize the cancellation.\n\nIf you encounter any difficulties or have further questions, our dedicated team is available to assist you. You can reach us during {{Customer Support Hours}} at {{Customer Support Phone Number}} or through the Live Chat feature on our website {{Website URL}}. We appreciate your understanding and value your satisfaction.'}, {'question': 'I cannot afford this order, cancel purchase {{Order Number}}', 'label': 'cancel_order', 'response': "I'm sensitive to the fact that you're facing financial difficulties and need to cancel your purchase with the order number {{Order Number}}. We're here to assist you with that, and I appreciate your transparency in sharing your situation with us. Let's proceed with the cancellation process:\n\n1. Access Your Account: Log in to our {{Online Company Portal Info}}.\n2. Locate Your Order History: Once you're logged in, navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction} ...

# %% [markdown]
# # Group Questions by Label

# %%
from collections import defaultdict

# Group questions by their labels
grouped_data = defaultdict(list)
for item in labeled_data:
    question = item['question']
    label = item['label']
    grouped_data[label].append(question)

# Print the grouped data to verify
for label, questions in grouped_data.items():
    print(f"Label: {label}")
    print(f"Sample Questions: {questions[:5]}")  # Show first 5 questions per label
    print("-" * 50)
# Out:
# Label: cancel_order
# Sample Questions: ['question about cancelling order {{Order Number}}', 'i have a question about cancelling oorder {{Order Number}}', 'i need help cancelling puchase {{Order Number}}', 'I need to cancel purchase {{Order Number}}', 'I cannot afford this order, cancel purchase {{Order Number}}']
# --------------------------------------------------
# Label: change_order
# Sample Questions: ['I try to change several bloody items of order {{Order Number}}', 'modifying purchase {{Order Number}}', 'want help adding an item to order {{Order Number}}', 'need to change order {{Order Number}} how to do it', 'edit purchase {{Order Number}}']
# --------------------------------------------------
# Label: change_shipping_address
# Sample Questions: ['give me information about a delivery address modification', 'need to update my address', 'I entered a wrong address, update it', 'i have an trouble editing the address', 'help modifying the shipping address']
# --------------------------------------------------
# Label: check_cancellation_fee
# Sample Questions: ["I can't ifnd the bloody termination charge, I need help", 'what is the fee for canceling the contract?', 'could I check the withdrawal charge?', 'i need help to see the early termination penalty', 'need assistance to see the withdrawal fee']
# --------------------------------------------------
# Label: check_invoice
# Sample Questions: ['show me invoice{{Invoice Number}}', 'need to see my invoicesfrom {{Person Name}}', 'I have to see my invoice from {{Person Name}}, help me', 'can you help me seeing the invoice from {{Person Name}}?', 'how can I locate the invoice #37777?']
# --------------------------------------------------
# Label: check_payment_methods
# Sample Questions: ['I try to list your available payment methoids', 'I nneed help to list the accepted payment methods', 'could you help me check what payment options are available?', 'see ur payment methods', 'I have got to list the allowed payment modalities, help me']
# --------------------------------------------------
# Label: check_refund_policy
# Sample Questions: ['i do not know hoow i could check ur reimbursement policy', 'help me check your money bck guarantee', 'need assistance to check in what cases can i request refunds', 'can I check in what cases can I ask to be reimbursed?', 'could you show me in what situations can I ask for refunds?']
# --------------------------------------------------
# Label: complaint
# Sample Questions: ['help me to file a claim', 'where can i make a consumer claim against ur organization', 'want help to make a consumer complaint against ur company', "I'm not happy with ur service need help to file a complaint", 'help to make a complaint']
# --------------------------------------------------
# Label: contact_customer_service
# Sample Questions: ['I want help to speak to customer support', 'do you have a free number to talk to customer assistance?', 'I try to see what hours customer service aailable is', 'do you have a mail to get in touch with cusomer assistance?', 'where can I see what hours I can reach customer support?']
# --------------------------------------------------
# Label: contact_human_agent
# Sample Questions: ['I do not understand you, help me chatting with someone', 'can I talk to a person?', "I can't speak with a live agent", 'how do i contact someone', 'can ya help me contactsomebody']
# --------------------------------------------------
# Label: create_account
# Sample Questions: ['new {{Account Type}} acount for wife', 'how to open a different fucking {{Account Type}} account for my father?', 'new {{Account Type}} account', 'i have a problem with creating a freemium account', 'opdn {{Account Category}} account']
# --------------------------------------------------
# Label: delete_account
# Sample Questions: ['closing  platinum account', "I don't know how I can remove my standard account", 'what do i have to do to remove the {{Account Type}} account', 'I want to delete a {{Account Type}} account, help me', "I don't know what I have to do to remove my {{Account Category}} account"]
# --------------------------------------------------
# Label: delivery_options
# Sample Questions: ['could you help me check what delivery methods you offer?', 'can you help me see what shipping methods you offer?', 'do you ship to {{Delivery City}}?', 'help to see what delivery methods are available', 'where do I check what damn shipment options are available?']
# --------------------------------------------------
# Label: delivery_period
# Sample Questions: ['need help seeing when my packageis going to arrive', 'I need to see how soon can I expect my damn order, help me', "I don't know how to see how soon can I expect my parcel", 'help me to check how soon can I expect my article', 'I need to check how long it takes for my shipment to arrive']
# --------------------------------------------------
# Label: edit_account
# Sample Questions: ['correcting data on {{Account Type}} account', 'i have to edit my personal info', 'modifying info on {{Account Category}} account', 'correctdata on {{Account Type}} account', 'edit premium accont']
# --------------------------------------------------
# Label: get_invoice
# Sample Questions: ['i dont know what i need to do to download my bill #85632', 'want assistance to download invoice #85632', 'what do I need to do to get my bill from {{Person Name}}?', "I don't know what I need to do to get the bill #12588", 'need help getting the invoices from {{Person Name}}']
# --------------------------------------------------
# Label: get_refund
# Sample Questions: ['how do I get a compensation of my money?', 'i do not know what i have to do to get my money back', 'I want assistace to request a compensation of my money', 'I would like to request a damn refund of money', 'I want assistance obtaining a reimbursement of my money']
# --------------------------------------------------
# Label: newsletter_subscription
# Sample Questions: ['i try to unsubscribe to ur companu newsletter', 'need to cancel the company newslettef subscription help me', 'how can i cancel the subscription to the company newsletter', 'how do I receive your newsletter?', 'I have got to subscrie to the company newsletter']
# --------------------------------------------------
# Label: payment_issue
# Sample Questions: ['i cant make a payment where can i notify of an error', 'problem with payments', 'can you help me notifying of errors with online payment?', 'I do not know how I can notify of a payment issue', 'can uhelpme informing of a problem with payments']
# --------------------------------------------------
# Label: place_order
# Sample Questions: ['I have to order something, can I get some help?', 'how do I order a product?', 'want help to earn an few of your item', 'I am trying to order a few of your  product', 'help to buy some articles']
# --------------------------------------------------
# Label: recover_password
# Sample Questions: ['can I reset the PIN of my user profile?', "I can't retrieve my goddamn user access key", 'i do not know how to recover the pin code of my user profile', "I'm trying to retrieve the pas of my user profile", 'i do not know what i need to do to restore my pin code']
# --------------------------------------------------
# Label: registration_problems
# Sample Questions: ['I need support with my sign-up', 'can you help me to report errors with registrations?', 'ik do not know how i can notify of a sign-up problem', 'I want assistance to notify of an error with sign-up', 'notify of problem with signup']
# --------------------------------------------------
# Label: review
# Sample Questions: ['uhave a method to leave an opinion about ur services', 'I need help to leave a review about your products', 'do you have an address to leave some feedback?', 'i have to leave a comment about a service i need help', 'need to submit my feedback for a service can uhelp me']
# --------------------------------------------------
# Label: set_up_shipping_address
# Sample Questions: ['error setting the shipping address up', 'I want help to sdt up the new shipping address', 'I have a trouble entering a shipping address', 'I want help to set up my delivery address', 'there is a problem submitting my secondary shipping address']
# --------------------------------------------------
# Label: switch_account
# Sample Questions: ['switch user', 'i dont know how to change to the {{Account Type}} account', 'i do not know how to switch to the {{Account Type}} account', 'switch to freemium account', 'switching to gold account']
# --------------------------------------------------
# Label: track_order
# Sample Questions: ['needx help to check the ETA of purchase {{Order Number}}', 'ETA of purchase {{Order Number}}', 'need to check the eta of order {{Order Number}}', 'I cannot see purchase {{Order Number}} current status', 'can uhelp me to check the fucking eta of the order {{Order Number}}']
# --------------------------------------------------
# Label: track_refund
# Sample Questions: ['can I see if there is anything new on the reimbursement?', 'I expect a refund of {{Refund Amount}} dollars', 'how to know if there are any updates on my reimbursement?', 'i expect a reimbursement of {{Refund Amount}} dollars', "I don't know what to do to check the status of my rebate"]
# --------------------------------------------------

# %% [markdown]
# # Group Questions by TF-IDF and Cosine Similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# Function to group similar questions within each label
def group_similar_questions(questions):
    # Convert questions to TF-IDF vectors
    vectorizer = TfidfVectorizer()
    question_vectors = vectorizer.fit_transform(questions)
    
    # Calculate cosine similarity between all pairs of questions
    similarity_matrix = cosine_similarity(question_vectors)
    
    # Initialize clusters for similar questions
    clusters = defaultdict(list)
    visited = set()
    
    for i, question in enumerate(questions):
        if i not in visited:
            cluster = [question]
            visited.add(i)
            for j, similarity in enumerate(similarity_matrix[i]):
                if i != j and similarity > 0.7:  # Threshold for similarity, e.g., 0.7
                    cluster.append(questions[j])
                    visited.add(j)
            clusters[f'Cluster_{i}'] = cluster
    
    return clusters

# Apply the grouping within each label
all_clusters = defaultdict(dict)
for label, questions in grouped_data.items():
    print(f"Processing Label: {label}")
    clusters = group_similar_questions(questions)
    all_clusters[label] = clusters

# Print the clusters for each label
for label, clusters in all_clusters.items():
    print(f"Label: {label}")
    for cluster_name, cluster_questions in clusters.items():
        print(f"  {cluster_name}:")
        for question in cluster_questions:
            print(f"    {question}")
    print("-" * 50)
# Out:
# Processing Label: cancel_order
# Processing Label: change_order
# Processing Label: change_shipping_address
# Processing Label: check_cancellation_fee
# Processing Label: check_invoice
# Processing Label: check_payment_methods
# Processing Label: check_refund_policy
# Processing Label: complaint
# Processing Label: contact_customer_service
# Processing Label: contact_human_agent
# Processing Label: create_account
# Processing Label: delete_account
# Processing Label: delivery_options
# Processing Label: delivery_period
# Processing Label: edit_account
# Processing Label: get_invoice
# Processing Label: get_refund
# Processing Label: newsletter_subscription
# Processing Label: payment_issue
# Processing Label: place_order
# Processing Label: recover_password
# Processing Label: registration_problems
# Processing Label: review
# Processing Label: set_up_shipping_address
# Processing Label: switch_account
# Processing Label: track_order
# Processing Label: track_refund
# Label: cancel_order
#   Cluster_0:
#     question about cancelling order {{Order Number}}
#     have a question about cancelling order {{Order Number}}
#     question about canceling order {{Order Number}}
#     have a question about cancelling order {{Order Number}}
#     question about canceling purchase {{Order Number}}
#     question about cancelling purchase {{Order Number}}
#     question about canceling order {{Order Number}}
#     question about cancelling purchase {{Order Number}}
#     I have a question about canceling purchase {{Order Number}}
#     have a question about canceling order {{Order Number}}
#     question about canceling purchase {{Order Number}}
#     question about cancelling purchase {{Order Number}}
#     I have a question about canceling purchase {{Order Number}}
#     I have a question about canceling order {{Order Number}}
#     question about canceling purchase {{Order Number}}
#     question about cancelling purchase {{Order Number}}
#     question about canceling purchase {{Order Number}}
#     question about cancelling purchase {{Order Number}}
#     i have a question about  canceling order {{Order Number}}
#     question about canceling purchase {{Order Number}}
#     question about cancelling order {{Order Number}}
#     i have a question about cancelling order {{Order Number}}
#     have a question about canceling order {{Order Number}}
#     question about canceling order {{Order Number}}
#   Cluster_1:
#     i have a question about cancelling oorder {{Order Number}}
#     have a question about cancelling order {{Order Number}}
#     have a question about cancelling order {{Order Number}}
#     i have a question about cancelling order {{Order Number}}
#   Cluster_2:
#     i need help cancelling puchase {{Order Number}}
#     i need help cancelling puchase {{Order Number}}
#   Cluster_3:
#     I need to cancel purchase {{Order Number}}
#     need assistance to cancel order {{Order Number}}
#     i need help to cancel purchase {{Order Number}}
#     need to cancel purchase {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     i need help to cancel purchase {{Order Number}}
#     I need help to cancel purchase {{Order Number}}
#     i need assistance to cancel order {{Order Number}}
#     I need help to cancel purchase {{Order Number}}
#     I need assistance to cancel order {{Order Number}}
#     I need assistance to cancel order {{Order Number}}
#     I need help to cancel order {{Order Number}}
#     need assistance to cancel order {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     i need assistance to cancel order {{Order Number}}
#     need help to cancel purchase {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     i need assistance to cancel purchase {{Order Number}}
#     i need assistance to cancel order {{Order Number}}
#     I need help to cancel purchase {{Order Number}}
#     I need to cancel order {{Order Number}}
#     need help to cancel purchase {{Order Number}}
#     i need assistance to cancel order {{Order Number}}
#     I need assistance to cancel order {{Order Number}}
#     need assistance to cancel purchase {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     I need help to cancel purchase {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     I need help to cancel purchase {{Order Number}}
#   Cluster_4:
#     I cannot afford this order, cancel purchase {{Order Number}}
#     I cannot afford order {{Order Number}}
#     I cannot afford order {{Order Number}}
#     I cannot afford order {{Order Number}}
#     I cannot afford purchase {{Order Number}}
#     I cannot afford order {{Order Number}}
#     I cannot afford purchase {{Order Number}}
#     i cannot afford purchase {{Order Number}}
#     I cannot afford purchase {{Order Number}}
#     I cannot afford this article, cancel order {{Order Number}}
#   Cluster_5:
#     can you help me cancel order {{Order Number}}?
#     can you help me canceling order {{Order Number}}?
#     can you help me cancel purchase {{Order Number}}?
#     can you help me cancel purchase {{Order Number}}?
#     could you help me cancel purchase {{Order Number}}?
#     can you help me to cancel purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     could you help me cancel purchase {{Order Number}}?
#     can you help me cancelling order {{Order Number}}?
#     can you help me cancelling order {{Order Number}}?
#     can you help me to cancel order {{Order Number}}?
#     can you help me cancelling order {{Order Number}}?
#     can you help me to cancel order {{Order Number}} ?
#     can you help me cancel purchase {{Order Number}}?
#     could you help me cancel purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     can you help me to cancel purchase {{Order Number}}?
#     can you help me cancel purchase {{Order Number}}?
#     can you help me to cancel purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     can you help me canceling order {{Order Number}}?
#     can you help me to cancel purchase {{Order Number}}?
#     can you help me cancel purchase {{Order Number}}?
#     can you help me canceling purchase {{Order Number}}?
#     can you help me canceling order {{Order Number}}?
#     can you help me to cancel purchase {{Order Number}}?
#     can you help me canceling purchase {{Order Number}}?
#     can you help me  cancelling purchase {{Order Number}}?
#     can you help me canceling purchase {{Order Number}}?
#     can you help me canceling purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     can you help me to cancel order {{Order Number}} ?
#     can you help me canceling purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     can you help me to cancel order {{Order Number}}?
#   Cluster_6:
#     I can no longer afford order {{Order Number}}, cancel it
#     I can no longer afford purchase {{Order Number}}
#     I can no longer afford purchase {{Order Number}}
#     I can no longer afford order {{Order Number}}, help me cancel it
#     I can no longer afford order {{Order Number}}
#     i can no longer afford order {{Order Number}}
#     i can no longer afford purchase {{Order Number}}
#     I can no longer afford order {{Order Number}}
#     I can no longer afford purchase {{Order Number}}
#     I can no longer afford purchase {{Order Number}}
#     I can no longer afford order {{Order Number}}
#     I can no longer afford order {{Order Number}}, can I cancel it?
#     I can no longer afford purchase {{Order Number}}, cancel it
#     i can no longer afford order {{Order Number}} could i cancel it
#     I can no longer afford order {{Order Number}}, cancel it
#     I can no longer afford order {{Order Number}}
#     i can no longer afford purchase {{Order Number}}
#     I can no longer afford order {{Order Number}}
#     I can no longer afford purchase {{Order Number}}, cancel it
#     I can no longer afford purchase {{Order Number}}
#     I no longer want purchase {{Order Number}}, can you cancel it?
#   Cluster_7:
#     I am trying to cancel purchase {{Order Number}}
#     I'm trying to cancel order {{Order Number}}
#     I am trying to cancel order {{Order Number}}
#     I'm trying to cancel purchase {{Order Number}}
#     I'm trying to cancel order {{Order Number}}
#     I am trying to cancel purchaes {{Order Number}}
#     I am trying to cancel purchase {{Order Number}}
#     I am trying to cancel purchase {{Order Number}}
#     I am trying to cancel order {{Order Number}}
#     I am trying to cancel purchase {{Order Number}}
#     I am trying to cancel purchase {{Order Number}}
#     I'm trying to cancel purchase {{Order Number}}
#     I am trying to cancel purchaes {{Order Number}}
#   Cluster_8:
#     I have got to cancel purchase {{Order Number}}
#     I have got to cancel purchase {{Order Number}}
#     I have got to cancel purchase {{Order Number}}, help me
#     I have got to cancel purchase {{Order Number}}
#     I have got to cancel purchase {{Order Number}}
#     I have got to cancel purchase {{Order Number}}, help me
#     I have got to cancel purchase {{Order Number}}
#     I have got to cancel order {{Order Number}}
#   Cluster_9:
#     i need help canceling purchase {{Order Number}}
#     need help with canceling order {{Order Number}}
#     need help with canceling purchase {{Order Number}}
#     i need help with canceling purchase {{Order Number}}
#     i need assistance canceling purchase {{Order Number}}
#     I need help canceling purchase {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     i need help with canceling order {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     i need help with canceling order {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     need help with canceling order {{Order Number}}
#     help canceling purchase {{Order Number}}
#     need help canceling purchase {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     i need help cancelling purchase {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     I need help canceling order {{Order Number}}
#     need help with canceling purchase {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     I need help canceling purchase {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     need help with canceling purchase {{Order Number}}
#     I need help canceling purchase {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     i need help canceling order {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     need help with canceling purchase {{Order Number}}
#     I need help canceling purchase {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     need help cancelling purchase {{Order Number}}
#     I need help with canceling order {{Order Number}}
#     I need help with canceling order {{Order Number}}
#     I need help with canceling order {{Order Number}}
#     need help cancelling purchase {{Order Number}}
#     need help with canceling order {{Order Number}}
#     i need help cancelling purchase {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     i need help cancelling purchase {{Order Number}}
#     help canceling purchase {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     need help canceling purchase {{Order Number}}
#     i need help canceling order {{Order Number}}
#     help canceling order {{Order Number}}
#     help canceling purchase {{Order Number}}
#     i need help with canceling purchase {{Order Number}}
#     i need help with canceling order {{Order Number}}
#     help canceling purchase {{Order Number}}
#     i need help canceling purchase {{Order Number}}
#     help canceling purchase {{Order Number}}
#     I need help canceling purchase {{Order Number}}
#     i need help canceling order {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     I need help canceling order {{Order Number}}
#   Cluster_10:
#     i dont know what to do to cancel order {{Order Number}}
#     what do I have to do to cancel purchase {{Order Number}}?
#     what do I have to do to cancel order {{Order Number}}?
#     what do I need to do to cancel purchase {{Order Number}}?
#     what do I need to do to cancel order {{Order Number}}?
#     i dont know what to do to cancel order {{Order Number}}
#     i dont know what to do to cancel purchase {{Order Number}}
#     what do I need to do to cancel purchase {{Order Number}}?
#     what do I have to do to cancel order {{Order Number}}?
#     what do I have to do to cancel purchase {{Order Number}}?
#     what do i need to do to cancel order {{Order Number}}
#     what do I need to do to cancel purchase {{Order Number}}?
#     i dont know what to do to cancel purchase {{Order Number}}
#     I don't know what to do to cancel purchase {{Order Number}}
#     what do I need to do to cancel purchase {{Order Number}}?
#     what do i need to do to cancel order {{Order Number}}
#     i do not know what to do to cancel order {{Order Number}}
#     what do i need to do to cancel order {{Order Number}}
#     what do I need to do to cancel purchase {{Order Number}}?
#     I don't know what to do to cancel order {{Order Number}}
#     I don't know what to do to cancel purchase {{Order Number}}
#     i do not know what to do to cancel purchase {{Order Number}}
#     i dont know how to cancel order {{Order Number}}
#     what do I have to do to cancel purchase {{Order Number}}?
#     what do I have to do to cancel purchase {{Order Number}}?
#     what do i have to do to cancel purchase {{Order Number}}
#     what do I have to do to cancel purchase {{Order Number}}?
#     I don't know what to do to cancel purchase {{Order Number}}
#     I do not know what to do to cancel purchase {{Order Number}}
#     I do not know what to do to cancel purchase {{Order Number}}
#   Cluster_11:
#     I have a problem with cancelling purchase {{Order Number}}
#     problem with canceling purchase {{Order Number}}
#     problem with cancelling order {{Order Number}}
#     have a problem with canceling order {{Order Number}}
#     problem with cancelling order {{Order Number}}
#     problem with cancelling purchase {{Order Number}}
#     I have a problem with canceling purchase {{Order Number}}
#     have a problem with cancelling purchase {{Order Number}}
#     i have a problem with cancelling order {{Order Number}}
#     I have a problem with cancelling purchase {{Order Number}}
#     I have a problem with cancelling order {{Order Number}}
#     problem with canceling purchase {{Order Number}}
#     problem with cancelling order {{Order Number}}
#     I have a problem with canceling purchase {{Order Number}}
#     problem with cancelling purchase {{Order Number}}
#     I have a problem with cancelling order {{Order Number}}
#     problem with cancelling purchase {{Order Number}}
#     problem with cancelling purchase {{Order Number}}
#     I have a problem with cancelling purchase {{Order Number}}
#     have a problem with canceling order {{Order Number}}
#     problem with canceling purchase {{Order Number}}
#     problem with canceling purchase {{Order Number}}
#     I have a problem with canceling purchase {{Order Number}}
#     i have a problem with canceling purchase {{Order Number}}
#     I have a problem with cancelling purchase {{Order Number}}
#     I have a problem with cancelling purchase {{Order Number}}
#     have a problem with cancelling order {{Order Number}}
#     problem with cancelling purchase {{Order Number}}
#     have a problem with cancelling order {{Order Number}}
#     I have a problem with canceling purchase {{Order Number}}
#     i have a problem with cancelling order {{Order Number}}
#   Cluster_14:
#     help  me canceling purchase {{Order Number}}
#     help me cancelling purchase {{Order Number}}
#     help me cancelling purchase {{Order Number}}
#     help canceling purchase {{Order Number}}
#     help me cancel purchase {{Order Number}}
#     help me cancel purchase {{Order Number}}
#     help me canceling purchase {{Order Number}}
#     help me to cancel purchase {{Order Number}}
#     help me canceling purchase {{Order Number}}
#     help me cancel purchase {{Order Number}}
#     help me cancel purchase {{Order Number}}
#     help me canceling purchase {{Order Number}}
#     help me cancel purchase {{Order Number}}
#     help me to cancel purchase {{Order Number}}
#     help me cancelling purchase {{Order Number}}
#     help me canceling purchase {{Order Number}}
#     help canceling purchase {{Order Number}}
#     can you help me canceling purchase {{Order Number}}?
#     help  me cancelling purchase {{Order Number}}
#     help canceling purchase {{Order Number}}
#     can you help me canceling purchase {{Order Number}}?
#     help me to cancel purchase {{Order Number}}
#     can you help me canceling purchase {{Order Number}}?
#     help canceling purchase {{Order Number}}
#     help me cancelling purchase {{Order Number}}
#     help me to cancel purchase {{Order Number}}
#     can you help me canceling purchase {{Order Number}}?
#     help me cancelling purchase {{Order Number}}
#     help canceling purchase {{Order Number}}
#     can you help me canceling purchase {{Order Number}}?
#     help me canceling purchase {{Order Number}}
#     help me to cancel purchase {{Order Number}}
#   Cluster_17:
#     I bought the same item twice, cancel order {{Order Number}}
#   Cluster_19:
#     i want assistance canceling order {{Order Number}}
#     i want assistance cancelling order {{Order Number}}
#     want assistance to cancel order  {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     want assistance to cancel order {{Order Number}}
#     I want assistance canceling order {{Order Number}}
#     I want help canceling order {{Order Number}}
#     I want assistance to cancel order {{Order Number}}
#     I want assistance to cancel order {{Order Number}}
#     need assistance canceling order {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     i need assistance canceling order {{Order Number}}
#     I need assistance canceling order {{Order Number}}
#     want assistance canceling order {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     i want assistance cancelling order {{Order Number}}
#     i want help canceling order {{Order Number}}
#     i want help canceling order {{Order Number}}
#     i want help canceling order {{Order Number}}
#     I need assistance canceling order {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     want assistance cancelling order {{Order Number}}
#     want assistance canceling purchase {{Order Number}}
#     want assistance canceling purchase {{Order Number}}
#     I want help canceling order {{Order Number}}
#     i want assistance to cancel order {{Order Number}}
#     I want assistance cancelling order {{Order Number}}
#     want assistance cancelling order {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     need assistance canceling order {{Order Number}}
#     I want assistance canceling order {{Order Number}}
#     want assistance cancelling order {{Order Number}}
#     i want assistance canceling purchase {{Order Number}}
#     i want assistance canceling order {{Order Number}}
#     want assistance to cancel order {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     i want assistance to cancel order {{Order Number}}
#     assistance canceling order {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     want assistance to cancel order  {{Order Number}}
#     i want assistance to cancel order {{Order Number}}
#     I want assistance canceling order {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     I want assistance cancelling order {{Order Number}}
#     I want assistance to cancel order {{Order Number}}
#     i need assistance canceling order {{Order Number}}
#     I need assistance canceling order {{Order Number}}
#     assistance with canceling order {{Order Number}}
#     i want help canceling order {{Order Number}}
#     assistance with canceling order {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     i want assistance cancelling order {{Order Number}}
#     need assistance canceling order {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     want assistance canceling order {{Order Number}}
#   Cluster_21:
#     i have problems with canceling order {{Order Number}}
#     problems with cancelling order {{Order Number}}
#     problems with canceling purchase {{Order Number}}
#     have problems with canceling order {{Order Number}}
#     I have problems with cancelling purchase {{Order Number}}
#     have problems with canceling purchase {{Order Number}}
#     have problems with canceling order  {{Order Number}}
#     I have problems with canceling purchase {{Order Number}}
#     have problems with canceling purchase {{Order Number}}
#     i have problems with canceling order {{Order Number}}
#     I have problems with cancelling order {{Order Number}}
#     problems with cancelling order {{Order Number}}
#     i have problems with canceling order {{Order Number}}
#     I have problems with canceling purchase {{Order Number}}
#     problems with cancelling order {{Order Number}}
#     problems with canceling purchase {{Order Number}}
#     problems with canceling purchase {{Order Number}}
#     I have problems with cancelling purchase {{Order Number}}
#     i have problems with cancelling purchase {{Order Number}}
#     problems with cancelling order {{Order Number}}
#     I have problems with canceling purchase {{Order Number}}
#     problems with canceling purchase {{Order Number}}
#     have problems with canceling purchase {{Order Number}}
#     problems with canceling purchase {{Order Number}}
#     have problems with canceling order  {{Order Number}}
#     I have problems with canceling purchase {{Order Number}}
#     I have problems with canceling purchase {{Order Number}}
#     I have problems with cancelling order {{Order Number}}
#     I have problems with cancelling purchase {{Order Number}}
#     I have problems with cancelling purchase {{Order Number}}
#     I have problems with cancelling purchase {{Order Number}}
#     have problems with cancelling purchase {{Order Number}}
#     i have problems with  cancelling purchase {{Order Number}}
#   Cluster_22:
#     assistance with cancelling pucrhase {{Order Number}}
#     assistance with cancelling pucrhase {{Order Number}}
#   Cluster_24:
#     help cnceling order {{Order Number}}
#     problems with cnceling purchase {{Order Number}}
#     problems with cnceling purchase {{Order Number}}
#   Cluster_26:
#     need assistance cancelling order {{Order Number}}
#     i want assistance cancelling order {{Order Number}}
#     need assistance to cancel order {{Order Number}}
#     assistance cancelling purchase {{Order Number}}
#     i need help cancelling order {{Order Number}}
#     I need help cancelling order {{Order Number}}
#     need assistance cancelling order {{Order Number}}
#     need assistance cancelling purchase {{Order Number}}
#     need assistance canceling order {{Order Number}}
#     i need assistance canceling order {{Order Number}}
#     I need assistance cancelling purchase {{Order Number}}
#     I need assistance cancelling purchase {{Order Number}}
#     assistance cancelling purchase {{Order Number}}
#     I need assistance canceling order {{Order Number}}
#     i need assistance to cancel order {{Order Number}}
#     i need assistance cancelling purchase {{Order Number}}
#     I need assistance cancelling order {{Order Number}}
#     I need help cancelling order {{Order Number}}
#     I need assistance to cancel order {{Order Number}}
#     assistance cancelling purchase {{Order Number}}
#     I need assistance to cancel order {{Order Number}}
#     i want assistance cancelling order {{Order Number}}
#     assistance cancelling purchase {{Order Number}}
#     I need assistance cancelling order {{Order Number}}
#     need assistance to cancel order {{Order Number}}
#     I need assistance canceling order {{Order Number}}
#     I need assistance with cancelling order {{Order Number}}
#     want assistance cancelling order {{Order Number}}
#     I want assistance cancelling order {{Order Number}}
#     i need assistance to cancel order {{Order Number}}
#     want assistance cancelling order {{Order Number}}
#     i need assistance cancelling purchase {{Order Number}}
#     need assistance canceling order {{Order Number}}
#     I need assistance cancelling purchase {{Order Number}}
#     want assistance cancelling order {{Order Number}}
#     I need assistance cancelling purchase {{Order Number}}
#     I need assistance cancelling purchase {{Order Number}}
#     I need help cancelling order {{Order Number}}
#     I need assistance cancelling order {{Order Number}}
#     I need help cancelling order {{Order Number}}
#     i need assistance to cancel order {{Order Number}}
#     i need assistance cancelling purchase {{Order Number}}
#     I want assistance cancelling order {{Order Number}}
#     i need assistance canceling order {{Order Number}}
#     I need assistance canceling order {{Order Number}}
#     need assistance cancelling purchase {{Order Number}}
#     assistance cancelling purchase {{Order Number}}
#     need assistance cancelling order {{Order Number}}
#     assistance cancelling order {{Order Number}}
#     i need assistance to cancel order {{Order Number}}
#     I need assistance to cancel order {{Order Number}}
#     i need assistance cancelling order {{Order Number}}
#     i want assistance cancelling order {{Order Number}}
#     need assistance canceling order {{Order Number}}
#     I need assistance with cancelling order {{Order Number}}
#     need help cancelling order {{Order Number}}
#   Cluster_28:
#     assistnace cancelling order {{Order Number}}
#   Cluster_33:
#     i do not know how i can cancel purchase {{Order Number}}
#     I do not know how I can cancel purchase {{Order Number}}
#     I do not know how I can cancel purchase {{Order Number}}
#     i do not know how to cancel order {{Order Number}}
#     i do not know how to cancel order {{Order Number}}
#     I do not know how to cancel purchase {{Order Number}}
#     i do not know how i can cancel order {{Order Number}}
#     I do not know how I can cancel purchase {{Order Number}}
#     I do not know how I can cancel purchase {{Order Number}}
#     i do not know how to cancel order {{Order Number}}
#     I do not know how I could cancel purchase {{Order Number}}
#     i do not know how i can cancel order {{Order Number}}
#     I do not know how I can cancel purchase {{Order Number}}
#     I do not know how to cancel purchase {{Order Number}}
#     I do not know how to cancel order {{Order Number}}
#     i do not know how to cancel order {{Order Number}}
#     I do not know how to cancel purchase {{Order Number}}
#     I do not know how to cancel purchase {{Order Number}}
#     i do not know how i can canmcel order {{Order Number}}
#     I do not know how I can cancel order {{Order Number}}
#     i do not know how i can cancel order {{Order Number}}
#     I do not know how to cancel purchase {{Order Number}}
#     i do not know how i can canmcel order {{Order Number}}
#     i do not know how to cancel purchase {{Order Number}}
#   Cluster_38:
#     I would like to cancel purchase {{Order Number}}
#     I would like to cancel purchase {{Order Number}}, I need help
#     I would like to cancel purchase {{Order Number}}
#     I would like to cancel purchase {{Order Number}}
#     I would like to cancel purchase {{Order Number}}
#     I no longer want order {{Order Number}}, I would like to cancel it
#   Cluster_39:
#     i do not want these article i try to cancel order {{Order Number}}
#   Cluster_45:
#     could ya help me cancel order {{Order Number}}
#     can ya help me cancel purchase {{Order Number}}
#     can ya help me to cancel order {{Order Number}}
#     can ya help me cancel purchase {{Order Number}}
#     can ya help me cancel order {{Order Number}}
#     can ya help me cancel purchase {{Order Number}}
#   Cluster_46:
#     could you help me cancelling order {{Order Number}} ?
#     could you help me cancel purchase {{Order Number}}?
#     could you help me canceling purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     could you help me cancel purchase {{Order Number}}?
#     could you help me canceling purchase {{Order Number}}?
#     can you help me cancelling order {{Order Number}}?
#     can you help me cancelling order {{Order Number}}?
#     could you help me to cancel purchase {{Order Number}}?
#     can you help me cancelling order {{Order Number}}?
#     could you help me cancel purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     could you help me cancelling purchase {{Order Number}}?
#     could you help me to cancel purchase {{Order Number}}?
#     can you help me  cancelling purchase {{Order Number}}?
#     could you help me cancelling purchase {{Order Number}}?
#     could you help me to cancel purchase {{Order Number}}?
#     could you help me canceling purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#     can you help me cancelling purchase {{Order Number}}?
#   Cluster_47:
#     cance order {{Order Number}}
#     cance order {{Order Number}}
#     cance order {{Order Number}}
#     cance order {{Order Number}}
#     cance order {{Order Number}}
#   Cluster_49:
#     assistance with canceling purchase {{Order Number}}
#     i need assistance canceling purchase {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     assistance with canceling purchase {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     assistance with canceling purchase {{Order Number}}
#     help with canceling purchase {{Order Number}}
#     I need assistance with canceling purchase {{Order Number}}
#     i need assistance with canceling order {{Order Number}}
#     assistance with canceling purchase {{Order Number}}
#     help with canceling purchase {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     help with canceling purchase {{Order Number}}
#     help with canceling purchase {{Order Number}}
#     I need assistance with canceling purchase {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     assistance with cancelling purchase {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     i need assistance with canceling order {{Order Number}}
#     want assistance canceling purchase {{Order Number}}
#     want assistance canceling purchase {{Order Number}}
#     assistance with cancelling purchase {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     i need assistance with canceling purchase {{Order Number}}
#     need assistance with canceling order {{Order Number}}
#     i want assistance canceling purchase {{Order Number}}
#     I need assistance with canceling purchase {{Order Number}}
#     assistance with cancelling purchase {{Order Number}}
#     assistance with canceling purchase {{Order Number}}
#     help with canceling purchase {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     assistance canceling order {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     I need assistance with canceling order {{Order Number}}
#     I need assistance canceling purchase {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#     assistance with cancelling purchase {{Order Number}}
#     assistance with cancelling purchase {{Order Number}}
#     assistance with canceling order {{Order Number}}
#     need assistance with canceling order {{Order Number}}
#     assistance with canceling order {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     i need assistance with canceling order {{Order Number}}
#     assistance canceling purchase {{Order Number}}
#   Cluster_50:
#     canceling order {{Order Number}}
#     canceling purchase {{Order Number}}
#     canceling order
#     canceling purchase {{Order Number}}
#     canceling purchase {{Order Number}}
#     canceling order {{Order Number}}
#     canceling purchase {{Order Number}}
#     canceling order {{Order Number}}
#     canceling order {{Order Number}}
#     assistance canceling order {{Order Number}}
#     help canceling order {{Order Number}}
#     canceling purchase {{Order Number}}
#     canceling order {{Order Number}}
#   Cluster_51:
#     how to cancel order {{Order Number}}
#     how do i cancel order {{Order Number}}
#     how to cancel purchase {{Order Number}}?
#     how can I cancel order {{Order Number}}?
#     how do i cancel order {{Order Number}}
#     how to cancel purchase {{Order Number}}?
#     how to cancel order {{Order Number}}?
#     how to cancel purchase {{Order Number}}?
#   Cluster_54:
#     I can't afford purchase {{Order Number}}
#     I can't afford purchase {{Order Number}}
#     I can't afford purchase {{Order Number}}
#     I can't afford order {{Order Number}}
#     I can't afford order {{Order Number}}
#     I can't afford order {{Order Number}}, how can I cancel it?
#     I can't afford order {{Order Number}}
#     I can't afford order {{Order Number}}
#     I can't afford purchase {{Order Number}}
#     I can't afford purchase {{Order Number}}
#   Cluster_56:
#     I ordered some item, cancel purchase {{Order Number}}
#     I have ordered some item, cancel purchase {{Order Number}}
#   Cluster_58:
#     I can't afford order {{Order Number}}, help me cancelling it
#     I can no longer afford order {{Order Number}}, help me cancel it
#     I can't afford order {{Order Number}}, help me cancelling it
#     I can't afford order {{Order Number}}, how can I cancel it?
#     I can't afford order {{Order Number}}, I need help to cancel it
#     I can't afford purchase {{Order Number}}, I need help canceling it
#   Cluster_60:
#     I try to cancel purchase {{Order Number}}
#     i try to cancel order {{Order Number}}
#     I try to cancel purchase {{Order Number}}
#     I try to cancel purchase {{Order Number}}
#     I try to cancel purchase {{Order Number}}
#     i try to cancel order {{Order Number}}
#     i try to cancel purchase {{Order Number}}
#   Cluster_62:
#     I cannot pay for the last purchase I have made, cancel it
#   Cluster_65:
#     I want to cancle purchase {{Order Number}}
#     I want assistance to cancle purchase {{Order Number}}
#     I want help to cancle purchase {{Order Number}}
#     I want help to cancle purchase {{Order Number}}
#     I want assistance to cancle purchase {{Order Number}}
#   Cluster_66:
#     help me to cancel my  last goddamn purchase
#   Cluster_67:
#     I have a problem witrh cancelling purchase {{Order Number}}
#   Cluster_68:
#     can  uhelp me canceling order {{Order Number}}
#     can uhelp me cancelling purchase {{Order Number}}
#     can uhelp me canceling order {{Order Number}}
#     can uhelp me canceling purchase {{Order Number}}
#     can  uhelp me canceling order {{Order Number}}
#     can uhelp me to cancel purchase {{Order Number}}
#     can uhelp me cancelling order {{Order Number}}
#     can uhelp me canceling purchase {{Order Number}}
#     can uhelp me to cancel purchase {{Order Number}}
#     can uhelp me cancelling purchase {{Order Number}}
#     can uhelp me canceling purchase {{Order Number}}
#     can uhelp me cancelling purchase {{Order Number}}
#   Cluster_70:
#     I need assistancde cancelling order {{Order Number}}
#   Cluster_71:
#     I bought some item, cancel order {{Order Number}}
#     I bought some item, cancel order {{Order Number}}
#     I bought some item, cancel order {{Order Number}}
#     I bought some item, cancel purchase {{Order Number}}
#     I have bought some item, I have to cancel order {{Order Number}}
#   Cluster_72:
#     need help with cancelling order {{Order Number}}
#     need help with canceling order {{Order Number}}
#     need help with canceling purchase {{Order Number}}
#     i need help with canceling purchase {{Order Number}}
#     i need help cancelling order {{Order Number}}
#     I need help cancelling order {{Order Number}}
#     I need help with cancelling order {{Order Number}}
#     help with cancelling purchase {{Order Number}}
#     help with cancelling purchase {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     i need help with canceling order {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     i need help with canceling order {{Order Number}}
#     need help with canceling order {{Order Number}}
#     I need help cancelling order {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     i need help cancelling purchase {{Order Number}}
#     I need help with cancelling purchase {{Order Number}}
#     need help with canceling purchase {{Order Number}}
#     help  with cancelling order {{Order Number}}
#     I need help with cancelling purchase {{Order Number}}
#     I need assistance with cancelling order {{Order Number}}
#     need help with canceling purchase {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     help with cancelling purchase {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     need help with canceling purchase {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     help cancelling order {{Order Number}}
#     need help cancelling purchase {{Order Number}}
#     i need help with cancelling order {{Order Number}}
#     I need help with cancelling order {{Order Number}}
#     I need help with canceling order {{Order Number}}
#     I need help with cancelling purchase {{Order Number}}
#     I need help with canceling order {{Order Number}}
#     I need help with canceling order {{Order Number}}
#     I need help cancelling order {{Order Number}}
#     need help cancelling purchase {{Order Number}}
#     need help with canceling order {{Order Number}}
#     help with cancelling order {{Order Number}}
#     help  with cancelling order {{Order Number}}
#     i need help cancelling purchase {{Order Number}}
#     i need help cancelling purchase {{Order Number}}
#     i need help with cancelling purchase {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     I need help cancelling purchase {{Order Number}}
#     i need help with cancelling order {{Order Number}}
#     I need help cancelling order {{Order Number}}
#     need help with cancelling purchase {{Order Number}}
#     i need help with cancelling order {{Order Number}}
#     i need help with canceling purchase {{Order Number}}
#     i need help with canceling order {{Order Number}}
#     I need help with cancelling purchase {{Order Number}}
#     help with cancelling purchase {{Order Number}}
#     I need help with cancelling order {{Order Number}}
#     I need help with canceling purchase {{Order Number}}
#     I need assistance with cancelling order {{Order Number}}
#     need help cancelling order {{Order Number}}
#     I need help with cancelling purchase {{Order Number}}
#   Cluster_73:
#     I can't pay for this item, can I cancel order {{Order Number}}?
#     I can't pay for purchase {{Order Number}}
#     I can't pay for this item, cancel order {{Order Number}}
#     I can't pay  for order {{Order Number}}
#     I can't pay for purchase {{Order Number}}
#     I can't pay for purchase {{Order Number}}
#     I can't pay for purchase {{Order Number}}
#   Cluster_74:
#     I need help cacneling order {{Order Number}}
#   Cluster_75:
#     where could I cancel purchase {{Order Number}}?
#     where to cancel purchase {{Order Number}}
#     where could I cancel purchase {{Order Number}}?
#     where to cancel purchase {{Order Number}}?
#     where could I cancel purchase {{Order Number}}?
#     where could I cancel purchase {{Order Number}}?
#     where could I cancel purchase {{Order Number}}?
#     where to cancel purchase {{Order Number}}?
#   Cluster_76:
#     i bought some damn item help to cancep order {{Order Number}}
#   Cluster_79:
#     whag do i need to do to cancel order {{Order Number}}
#     what do I need to do to cancel purchase {{Order Number}}?
#     what do I need to do to cancel order {{Order Number}}?
#     what do I need to do to cancel purchase {{Order Number}}?
#     what do i need to do to cancel order {{Order Number}}
#     what do I need to do to cancel purchase {{Order Number}}?
#     what do I need to do to cancel purchase {{Order Number}}?
#     what do i need to do to cancel order {{Order Number}}
#     what do i need to do to cancel order {{Order Number}}
#     what do I need to do to cancel purchase {{Order Number}}?
#     whag do i need to do to cancel order {{Order Number}}
#   Cluster_82:
#     I want assistance to cancel purchase {{Order Number}}
#     want assistance to cancel order  {{Order Number}}
#     want assistance to cancel order {{Order Number}}
#     i want help to cancel purchase {{Order Number}}
#     I want assistance to cancel order {{Order Number}}
#     I want assistance to cancel order {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     want help to cancel purchase {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     want assistance cancelling purchase {{Order Number}}
#     assistance to cancel order {{Order Number}}
#     I want to cancel order {{Order Number}}
#     i want help to cancel order {{Order Number}}
#     assistance to cancel purchase {{Order Number}}
#     I want assistance to cancel purchase {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     I want assistance to cancel purchase {{Order Number}}
#     want assistance canceling purchase {{Order Number}}
#     want assistance canceling purchase {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     i want assistance to cancel order {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     i want help to cancel purchase {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#     i want assistance canceling purchase {{Order Number}}
#     assistance to cancel purchase {{Order Number}}
#     want assistance cancelling purchase {{Order Number}}
#     want help to cancel order {{Order Number}}
#     want assistance to cancel order {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     i want assistance to cancel order {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     want assistance to cancel order  {{Order Number}}
#     i want assistance to cancel order {{Order Number}}
#     I want help to cancel order {{Order Number}}
#     i want assistance to cancel purchase {{Order Number}}
#     i want assistance to cancel purchase {{Order Number}}
#     i need assistance to cancel purchase {{Order Number}}
#     i want help to cancel order {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#     I want assistance to cancel order {{Order Number}}
#     assistance to cancel purchase {{Order Number}}
#     I want to cancel purchase {{Order Number}}
#     assistance to cancel purchase {{Order Number}}
#     I want help to cancel order {{Order Number}}
#     i want help to cancel order {{Order Number}}
#     want help to cancel purchase {{Order Number}}
#     I want assistance to cancel purchase {{Order Number}}
#     need assistance to cancel purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     I want assistance canceling purchase {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#     i want help to cancel purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     want help to cancel purchase {{Order Number}}
#     I need assistance to cancel purchase {{Order Number}}
#     I want to cancel purchase {{Order Number}}
#     I want assistance to cancel purchase {{Order Number}}
#     assistance to cancel purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#   Cluster_83:
#     cancelling order
#     cancelling order {{Order Number}}
#     cancelling purchase {{Order Number}}
#     cancelling order {{Order Number}}
#     cancelling order {{Order Number}}
#     cancelling purchase {{Order Number}}
#     cancelling purchase {{Order Number}}
#     help cancelling order {{Order Number}}
#     cancelling order {{Order Number}}
#     cancelling purchase {{Order Number}}
#     assistance cancelling order {{Order Number}}
#     cancelling order {{Order Number}}
#     cancelling purchase {{Order Number}}
#   Cluster_84:
#     i want help cancelling purchase {{Order Number}}
#     i want help to cancel purchase {{Order Number}}
#     i want help cancelling purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     want help to cancel purchase {{Order Number}}
#     help cancelling purchase {{Order Number}}
#     want assistance cancelling purchase {{Order Number}}
#     I want help cancelling purchase {{Order Number}}
#     I want help cancelling purchase {{Order Number}}
#     i want help canceling purchase {{Order Number}}
#     want help cancelling purchase {{Order Number}}
#     i want help cancelling order {{Order Number}}
#     I want help cancelling purchase {{Order Number}}
#     want help cancelling purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     i want help to cancel purchase {{Order Number}}
#     help cancelling order {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#     want assistance cancelling purchase {{Order Number}}
#     want help canceling purchase {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#     help cancelling purchase {{Order Number}}
#     I want help cancelling purchase {{Order Number}}
#     I want help canceling purchase {{Order Number}}
#     I want help canceling purchase {{Order Number}}
#     I want help canceling purchase {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#     i want help cancelling order {{Order Number}}
#     I want help cancelling purchase {{Order Number}}
#     want help to cancel purchase {{Order Number}}
#     I want help canceling purchase {{Order Number}}
#     I want help canceling purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#     I want help cancelling order {{Order Number}}
#     i want help to cancel purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     want help canceling purchase {{Order Number}}
#     want help cancelling purchase {{Order Number}}
#     want help to cancel purchase {{Order Number}}
#     want help canceling purchase {{Order Number}}
#     i want help canceling purchase {{Order Number}}
#     I want help to cancel purchase {{Order Number}}
#     I want assistance cancelling purchase {{Order Number}}
#   Cluster_91:
#     I bought some articles, help me to cancel order {{Order Number}}
#     I bought some articles, how to cancel order {{Order Number}}?
#     I bought some bloody articles, cancel order {{Order Number}}
#   Cluster_95:
#     I want help cancellkng purchase {{Order Number}}
#     I want help cancellkng purchase {{Order Number}}
#     I want help cancellkng purchase {{Order Number}}
#     I want help cancellkng purchase {{Order Number}}
#   Cluster_100:
#     where can I cancel order {{Order Number}}?
#     where to cancel purchase {{Order Number}}
#     where can I cancel order {{Order Number}}?
#     where do i cancel purchase {{Order Number}}
#     where can i cancel purchase {{Order Number}}
#     where can I cancel purchase {{Order Number}}?
#     where can I cancel purchase {{Order Number}}?
#     where do I cancel purchase {{Order Number}}?
#     where can I cancel purchase {{Order Number}}?
#     where do I cancel purchase {{Order Number}}?
#     where to cancel purchase {{Order Number}}?
#     where do I cancel purchase {{Order Number}}?
#     where can I cancel purchase {{Order Number}}?
#     where can I cancel purchase {{Order Number}}?
# ...
#     how to see if there is anything wrong with the restitution?
#     how to check if there is anything wrong with my rebate?
#     I want help seeing if there is anything wrong with my refund
#     I can't check if there is anything wrong with my rebate
#     how can I see if there is anything wrong with my rebate?
#     I want to know if there is anything wrong with my rebate
#     I have to know if there is anything wrong with the rebate
#     help me check if there is anything wrong with my refund
#     help knowing if there is anything wrong with the restitution
#     know if there is anything wrong with the refund
#     help to see if there is anything wrong with my restitution
#     I can't see if there is anything wrong with the restitution
#     assistance seeing if there is anything wrong with my refund
#   Cluster_477:
#     I have to check if there is anything new on the restitution
#     i cannot check if there is anything new on the reimbursement
#     how to know if there is anything new on the rebate?
#     there is anything new on the reimbursement
#     I can't check if there is anything new on the compensation
#     i cannot check if there is anything new on the rebate
#     can I know if there is anything new on the restitution?
#     know if there is anything new on my restitution
#     know if there is anything new on the rebate
#     help me to check if there is anything new on the restitution
#     I have to see if there is anything new on my refund, help me
#     I want help to check if there is anything new on my rebate
#     could I check if there is anything new on the compensation?
#     need to know if there is anything new on the restitution
#     I need to see if there is anything new on the compensation
#     I want to see if there is anything new on the restitution
#     how can I check if there is anything new on the restitution?
#     I need to know if there is anything new on the restitution
#   Cluster_481:
#     I'm trying to check the status of my compensation
#     I am trying to check my compensation current status
#     I am trying to see the current status of the compensation
#     I am trying to check my rebate status
#     I am trying to check the status of the restitution
#   Cluster_483:
#     anything new on my goddamn reimbursement
#   Cluster_490:
#     i expect a rebate of {{Currency Symbol}}{{Refund Amount}} has it been processd already
#     i expect a restitution of {{Currency Symbol}}{{Refund Amount}} has it been processed already
#     I expect a refund of {{Currency Symbol}}{{Refund Amount}}, has it been processed already?
#     i expect a refund of {{Currency Symbol}}{{Refund Amount}} has it been processed already
#   Cluster_503:
#     showing refund status
#     showing reimbursement status
#   Cluster_508:
#     can uhelp me knowing if there are any news on my restitution
#     can uhelp me see if there are any news on my refund
#   Cluster_511:
#     can you show me the compensation status?
#     can you help me see the compensation status?
#     can you show me the current status of my refund?
#     can you show me the rebate current status?
#   Cluster_515:
#     assistance to check the reimbursement status
#     want assistance to check the status of the rebate
#     I want assistance to check my reimbursement status
#   Cluster_519:
#     any news on my bloody reimbursement
#   Cluster_534:
#     I want to track the reimbursement, can you help me?
#     want help to track the reimbursement
#     I have to track my compensation, can you help me?
#     can you help me see the status of the reimbursement?
#   Cluster_536:
#     how could I track my restitution?
#     how could I track the compensation?
#   Cluster_539:
#     I ned help checking the rebate current status
#   Cluster_552:
#     I need to see the current status of my refund
#     I need help to check the current status of my refund
#     need help to see my rebate current status
#     need assistance to see my restitution current status
#     need help to see the status of my refund
#     I need to see the current status of the compensation
#     I need to check the current status of the reimbursement
#     I need help to see the current status of the refund
#   Cluster_562:
#     where to see the bloody rebate current status?
#   Cluster_565:
#     how do I see the current status of the reimbursement?
#     how to check the current status of the reimbursement?
#     how to see the reimbursement current status
#     how do i check the current status of the reimbursement
#     i do not know how i can see the reimbursement current status
#     how to see the current status of the rebate
#     how do I see the status of the reimbursement?
#     I do not know how I can see the current status of the refund
#     see the status of the reimbursement
#     how do I see the current status of the refund?
#     how do I check the current status of my restitution?
#   Cluster_566:
#     need to know if there are any updates on the ocmpensation
#     I need to see if there are any updates on the rebate
#     I need help to know if there are any updates on my refund
#     where to know if there are any updates on the refund?
#   Cluster_578:
#     where do I check the reimbursement current status?
#     where to see the current status of the reimbursement
#     where do i check the restitution status
#     how do i check the current status of the reimbursement
#   Cluster_581:
#     any news on the refund
#   Cluster_589:
#     want help knowing if there are any updates on my refund
#     want help to know if there are any updates on my restitution
#     help me knowing if there are any updates on the refund
#   Cluster_591:
#     I want help seeing if there are any news on my reimbursement
#     I want to know if there are any news on my refund
#     I want help to know if there are any news on the rebate
#     want help to see if there are any news on the rebate
#     help me seeing if there are any news on my reimbursement
#     I want help to see if there are any news on the compensation
#     want help to check if there are any news on my refund
#     I want to see if there are any news on my rebate
#     I want help to check if there are any news on the refund
#     i want help checking if there are any news on my restitution
#     help seeing if there are any updates on my reimbursement
#     i need help seeing if there are any news on the rebate
#     I need help seeing if there are any news on the compensation
#     assistance seeing if there are any news on my reimbursement
#     help me seeing if there are any updates on the reimbursement
#   Cluster_595:
#     I don't know how I can track my rebate
#     I don't know how I can check the rebate status
#     I don't know how to track my restitution
#     I don't know how I can check my restitution status
#     I don't know how I can see my compensation status
#     I don't know how I can check my compensation status
#     I don't know how to track my reimbursement
#     I don't know how I could track the compensation
#   Cluster_598:
#     i expecdt a refund of {{Refund Amount}} dollars
#     i expecdt a refund of {{Refund Amount}} dollars
#     i expecdt a refund of {{Refund Amount}} dollars
#     i expecdt a refund of {{Refund Amount}} dollars
#   Cluster_602:
#     I want to track my restitution
#     want assistance to track the restitution
#   Cluster_603:
#     where do I see my rebate status?
#     where to see the status of my rebate
#   Cluster_604:
#     i dont know what i have to do to track the restitution
#     what do I have to do to track the refund?
#     i dont know what to do to track my rebate
#     i dont know what i have to do to see the rebate status
#   Cluster_612:
#     anything new on the refund
#     there is anything new on the reimbursement
#   Cluster_618:
#     I need to check my goddamn restitution status
#   Cluster_619:
#     I have to see the status of the rebate, will you help me?
#     I have to see my refund current status, will you help me?
#     I need to see my rebate current status, will you help me?
#   Cluster_625:
#     help me to check the sxtatus of my reimbursement
#   Cluster_634:
#     I'm waiting for a rebateof {{Currency Symbol}}{{Refund Amount}}
#     I'm waiting for a rebateof {{Currency Symbol}}{{Refund Amount}}
#   Cluster_660:
#     i cant check my restitution current status
#   Cluster_661:
#     I want to check the current status of the refund
#     help to check the current status of the compensation
#     how to check the current status of the reimbursement?
#     want assistance to check the status of the rebate
#     I want help to check the current status of the reimbursement
#     i want help to check the current status of my compensation
#     want help to check the restitution status
#     I need to check the current status of the reimbursement
#   Cluster_675:
#     can you help me check the rebate current status?
#     can you help me to see the current status of my refund?
#     can you help me see the current status of my reimbursement?
#     can you help me to see the compensation current status?
#     can you help me see the current status of the rebate?
#     can you help me see the compensation status?
#     I need to check the rebate current status, can you help me?
#     can you help me to see the restitution status?
#     can you help me check my restitution status?
#     can you help me check the status of my compensation?
#     can you help me check the goddamn status of the rebate?
#     can you show me the rebate current status?
#     can you help me check the compensation current status?
#     can you help me see the status of the reimbursement?
#   Cluster_677:
#     help checking if there is anything new on the bloody rebate
#   Cluster_680:
#     I cannot know if there are any updates on my damn refund
#     I cannot see if there are any updates on my compensation
#   Cluster_690:
#     help to check the damn current status of the restitution
#     help to check the current status of the compensation
#     help me to check the status of the restitution
#   Cluster_695:
#     where can I check if there is anything enw on the refund?
#   Cluster_705:
#     I'm waiting for a reimbursement of 299dollars
#   Cluster_708:
#     I expect a refund of {{Currency Symbol}}{{Refund Amount}}, was it processeed
#   Cluster_709:
#     i expect a restitution of {{Currency Symbol}}{{Refund Amount}} has it been prcoessed
#     I expect a refund of {{Currency Symbol}}{{Refund Amount}}, has it been processed?
#   Cluster_730:
#     where could I check the current status of my restitution?
#     where can I check the current status of my rebate?
#     where could I check the current status of the compensation?
#     where could I check the rebate status?
#   Cluster_733:
#     seeing reimbursement status
#     i want help seeing my reimbursement status
#   Cluster_736:
#     can you help me know if there are any updates on my refund?
#     help me see if there are any updates on my reimbursement
#     I can't see if there are any updates on my compensation
#     want help to know if there are any updates on my restitution
#     I need help to know if there are any updates on my refund
#     help me seeing if there are any updates on my compensation
#     help me checking if there are any updates on my restitution
#     can I see if there are any updates on my rebate?
#     can you help me to see if there are any news on my refund?
#     can you help me check if there are any news on my refund?
#   Cluster_772:
#     I do not know how to know if there are any news on my rebate
#     I want to know if there are any news on my refund
#     how do i know if there are any updates on my rebate
#     help to know if there are any news on my restitution
#     assistance to know if there are any news on my refund
#     i do not know how to track my rebate
#   Cluster_796:
#     I am waitig for a damn reimbursement of {{Refund Amount}} dollars
#   Cluster_806:
#     what is my rebate status?
#   Cluster_835:
#     I expect a goddamn compensation of {{Currency Symbol}}{{Refund Amount}}, was it processed
#     I expect a restitution of {{Currency Symbol}}{{Refund Amount}}, was it processed
#     I expect a rebate of {{Currency Symbol}}{{Refund Amount}}, was it processed
#     I am waiting for a compensation of {{Currency Symbol}}{{Refund Amount}}, was it processed
#     I'm waiting for a restitution of {{Currency Symbol}}{{Refund Amount}} was it processed
#     I expect a restitution of {{Currency Symbol}}{{Refund Amount}}, was it processed
#     I expect a compensation of {{Refund Amount}} dollars, was it processed
#     i expect a rebate of {{Currency Symbol}}{{Refund Amount}} was it processed
#     I expect a compensation of {{Currency Symbol}}{{Refund Amount}}, was it processed already
#     i expect a compensation of {{Refund Amount}} dollars was it processed
#     I expect a restitution of {{Currency Symbol}}{{Refund Amount}}, was it processed
#     i expect a compensation of {{Currency Symbol}}{{Refund Amount}} was it processed
#     I'm waiting for a rebate of {{Currency Symbol}}{{Refund Amount}} was it processed
#   Cluster_839:
#     i dont know how to track my refund
#     i dont know how to check the current status of my rebate
#     i dont know what to do to track my rebate
#     i dont know how i could track the rebate
#   Cluster_843:
#     could I check if there are any updates on my goddamn rebate?
#     could I know if there are any updates on my rebate?
#     how could I see if there are any updates on my refund?
#   Cluster_844:
#     I would like to see my compensation status, how do I do it?
#     I would like to track the reimbursement, how could I do it?
#     I would like to see the status of my compensation
#   Cluster_846:
#     could I track my damn reimbursement?
#   Cluster_880:
#     check my reimbursement status
#     help me check the status of my reimbursement
#     check my refund status
#     can I check the current status of my reimbursement?
#   Cluster_891:
#     help me to check if there are nay news on the refund
#   Cluster_894:
#     check restitution current status
#     see restitution current status
#   Cluster_914:
#     I want to check the goddamn rebate status, how to do it?
#   Cluster_920:
#     I'm waiting for a reimbursement of 350dollars
#   Cluster_946:
#     could ya help me checking the current status of my refund
#     could ya help me check the compensation current status
#     could you help me checking the refund current status?
#   Cluster_947:
#     there is any updates on my rebate
#   Cluster_955:
#     I'm waiting for a goddamn compensation of {{Refund Amount}} dollars
#     I'm waiting for a compensation of {{Refund Amount}} dollars
#     I'm waiting for a compensation of {{Refund Amount}} dollars
#     I'm waiting for a compensation of {{Refund Amount}} dollars
#     I'm waiting for an goddamn restitution of {{Refund Amount}} dollars
#     I'm waiting for a compensation of {{Refund Amount}} dollars
#     i expect a goddamn reimbursement of {{Refund Amount}} dollars
#     I'm waiting for a compensation of {{Refund Amount}} dollars
#   Cluster_960:
#     I'm waitng for a reimbursement of {{Currency Symbol}}{{Refund Amount}} has it been processed
#     I expect a refund of {{Currency Symbol}}{{Refund Amount}}, has it been processed?
#     I am waiting for a refund of {{Currency Symbol}}{{Refund Amount}}, has it been processed?
#     I'm waiting for an refund of {{Currency Symbol}}{{Refund Amount}} has it been processed
#   Cluster_961:
#     I expect a damn rebate of {{Refund Amount}} dollars
#     I expect a rebate of {{Refund Amount}} dollars
#     I am waiting for a damn rebate of {{Refund Amount}} dollars
#     I expect a rebate of {{Refund Amount}} dollars
#     I expect a rebate of {{Refund Amount}} dollars
#     i expect a rebate of {{Refund Amount}} dollars
#     i expect a rebate of {{Refund Amount}} dollars
#     I expect a rebate of {{Refund Amount}} dollars
#     i expect a rebate of {{Refund Amount}} dollars
#     i expect a rebate of {{Refund Amount}} dollars
#     i expect a damn restitution of {{Currency Symbol}}{{Refund Amount}}
#     I expect a rebate of {{Refund Amount}} dollars
#     i expect a rebate of {{Refund Amount}} dollars
#   Cluster_974:
#     need to check the rebate curent status how to do it
# --------------------------------------------------

# %% [markdown]
# # Data Preprocessing

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download NLTK stopwords and WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize the lemmatizer and stop words
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Preprocessing function
def preprocess_text(text):
    # Lowercasing
    text = text.lower()
    
    # Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)
    
    # Tokenization
    tokens = word_tokenize(text)
    
    # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    
    # Lemmatization
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    # Remove leading and trailing whitespace for each token (although tokenization typically handles this)
    tokens = [token.strip() for token in tokens]
    
    # Join tokens back into a single string
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# Apply preprocessing to all questions
for label, questions in grouped_data.items():
    grouped_data[label] = [preprocess_text(question) for question in questions]

# Preview the preprocessed data
for label, questions in grouped_data.items():
    print(f"Label: {label}")
    print(f"Sample Preprocessed Questions: {questions[:5]}")
    print("-" * 50)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\boeylee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\boeylee\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\boeylee\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Label: cancel_order
# Sample Preprocessed Questions: ['question cancelling order order number', 'question cancelling oorder order number', 'need help cancelling puchase order number', 'need cancel purchase order number', 'afford order cancel purchase order number']
# --------------------------------------------------
# Label: change_order
# Sample Preprocessed Questions: ['try change several bloody item order order number', 'modifying purchase order number', 'want help adding item order order number', 'need change order order number', 'edit purchase order number']
# --------------------------------------------------
# Label: change_shipping_address
# Sample Preprocessed Questions: ['give information delivery address modification', 'need update address', 'entered wrong address update', 'trouble editing address', 'help modifying shipping address']
# --------------------------------------------------
# Label: check_cancellation_fee
# Sample Preprocessed Questions: ['cant ifnd bloody termination charge need help', 'fee canceling contract', 'could check withdrawal charge', 'need help see early termination penalty', 'need assistance see withdrawal fee']
# --------------------------------------------------
# Label: check_invoice
# Sample Preprocessed Questions: ['show invoiceinvoice number', 'need see invoicesfrom person name', 'see invoice person name help', 'help seeing invoice person name', 'locate invoice 37777']
# --------------------------------------------------
# Label: check_payment_methods
# Sample Preprocessed Questions: ['try list available payment methoids', 'nneed help list accepted payment method', 'could help check payment option available', 'see ur payment method', 'got list allowed payment modality help']
# --------------------------------------------------
# Label: check_refund_policy
# Sample Preprocessed Questions: ['know hoow could check ur reimbursement policy', 'help check money bck guarantee', 'need assistance check case request refund', 'check case ask reimbursed', 'could show situation ask refund']
# --------------------------------------------------
# Label: complaint
# Sample Preprocessed Questions: ['help file claim', 'make consumer claim ur organization', 'want help make consumer complaint ur company', 'im happy ur service need help file complaint', 'help make complaint']
# --------------------------------------------------
# Label: contact_customer_service
# Sample Preprocessed Questions: ['want help speak customer support', 'free number talk customer assistance', 'try see hour customer service aailable', 'mail get touch cusomer assistance', 'see hour reach customer support']
# --------------------------------------------------
# Label: contact_human_agent
# Sample Preprocessed Questions: ['understand help chatting someone', 'talk person', 'cant speak live agent', 'contact someone', 'ya help contactsomebody']
# --------------------------------------------------
# Label: create_account
# Sample Preprocessed Questions: ['new account type acount wife', 'open different fucking account type account father', 'new account type account', 'problem creating freemium account', 'opdn account category account']
# --------------------------------------------------
# Label: delete_account
# Sample Preprocessed Questions: ['closing platinum account', 'dont know remove standard account', 'remove account type account', 'want delete account type account help', 'dont know remove account category account']
# --------------------------------------------------
# Label: delivery_options
# Sample Preprocessed Questions: ['could help check delivery method offer', 'help see shipping method offer', 'ship delivery city', 'help see delivery method available', 'check damn shipment option available']
# --------------------------------------------------
# Label: delivery_period
# Sample Preprocessed Questions: ['need help seeing packageis going arrive', 'need see soon expect damn order help', 'dont know see soon expect parcel', 'help check soon expect article', 'need check long take shipment arrive']
# --------------------------------------------------
# Label: edit_account
# Sample Preprocessed Questions: ['correcting data account type account', 'edit personal info', 'modifying info account category account', 'correctdata account type account', 'edit premium accont']
# --------------------------------------------------
# Label: get_invoice
# Sample Preprocessed Questions: ['dont know need download bill 85632', 'want assistance download invoice 85632', 'need get bill person name', 'dont know need get bill 12588', 'need help getting invoice person name']
# --------------------------------------------------
# Label: get_refund
# Sample Preprocessed Questions: ['get compensation money', 'know get money back', 'want assistace request compensation money', 'would like request damn refund money', 'want assistance obtaining reimbursement money']
# --------------------------------------------------
# Label: newsletter_subscription
# Sample Preprocessed Questions: ['try unsubscribe ur companu newsletter', 'need cancel company newslettef subscription help', 'cancel subscription company newsletter', 'receive newsletter', 'got subscrie company newsletter']
# --------------------------------------------------
# Label: payment_issue
# Sample Preprocessed Questions: ['cant make payment notify error', 'problem payment', 'help notifying error online payment', 'know notify payment issue', 'uhelpme informing problem payment']
# --------------------------------------------------
# Label: place_order
# Sample Preprocessed Questions: ['order something get help', 'order product', 'want help earn item', 'trying order product', 'help buy article']
# --------------------------------------------------
# Label: recover_password
# Sample Preprocessed Questions: ['reset pin user profile', 'cant retrieve goddamn user access key', 'know recover pin code user profile', 'im trying retrieve pa user profile', 'know need restore pin code']
# --------------------------------------------------
# Label: registration_problems
# Sample Preprocessed Questions: ['need support signup', 'help report error registration', 'ik know notify signup problem', 'want assistance notify error signup', 'notify problem signup']
# --------------------------------------------------
# Label: review
# Sample Preprocessed Questions: ['uhave method leave opinion ur service', 'need help leave review product', 'address leave feedback', 'leave comment service need help', 'need submit feedback service uhelp']
# --------------------------------------------------
# Label: set_up_shipping_address
# Sample Preprocessed Questions: ['error setting shipping address', 'want help sdt new shipping address', 'trouble entering shipping address', 'want help set delivery address', 'problem submitting secondary shipping address']
# --------------------------------------------------
# Label: switch_account
# Sample Preprocessed Questions: ['switch user', 'dont know change account type account', 'know switch account type account', 'switch freemium account', 'switching gold account']
# --------------------------------------------------
# Label: track_order
# Sample Preprocessed Questions: ['needx help check eta purchase order number', 'eta purchase order number', 'need check eta order order number', 'see purchase order number current status', 'uhelp check fucking eta order order number']
# --------------------------------------------------
# Label: track_refund
# Sample Preprocessed Questions: ['see anything new reimbursement', 'expect refund refund amount dollar', 'know update reimbursement', 'expect reimbursement refund amount dollar', 'dont know check status rebate']
# --------------------------------------------------

# %% [markdown]
# # Data Splitting

# %%
from sklearn.model_selection import train_test_split

# Create a dataset for each label with preprocessed questions and their labels
all_data = []
all_labels = []
for label, questions in grouped_data.items():
    for question in questions:
        all_data.append(question)
        all_labels.append(label)

# Split the data into training and testing sets (80% training, 20% testing)
train_data, test_data, train_labels, test_labels = train_test_split(all_data, all_labels, test_size=0.2, random_state=42)

# Verify the split
print(f"Training data: {len(train_data)} samples")
print(f"Testing data: {len(test_data)} samples")
# Out:
# Training data: 21497 samples
# Testing data: 5375 samples

# %% [markdown]
# # Convert the textual data into numerical features

# %% [markdown]
# ## TF-IDF Conversion

# %%
# !pip install scikit-learn

from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the training data into numerical features (TF-IDF)
train_features = tfidf_vectorizer.fit_transform(train_data)

# Transform the test data using the same vectorizer (do not refit)
test_features = tfidf_vectorizer.transform(test_data)

# Print the shape of the transformed data
print(f"Train Features Shape: {train_features.shape}")
print(f"Test Features Shape: {test_features.shape}")
# Out:
# Requirement already satisfied: scikit-learn in c:\users\boeylee\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Train Features Shape: (21497, 2396)
# Test Features Shape: (5375, 2396)

# %%
import joblib

# Save the TF-IDF vectorizer
joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']

# %% [markdown]
# ## K-Nearest Neighbors (KNN)

# %%
# Install required libraries if not already installed
# !pip install scikit-learn

# Import necessary libraries
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import pandas as pd

# Assuming the following variables are defined from your previous steps
# train_data, test_data, train_labels, test_labels

# Convert the textual data into numerical features using TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the training data into numerical features (TF-IDF)
train_features = tfidf_vectorizer.fit_transform(train_data)

# Transform the test data using the same vectorizer (do not refit)
test_features = tfidf_vectorizer.transform(test_data)

# Initialize the KNN model
knn_model = KNeighborsClassifier(n_neighbors=10)  # You can change the number of neighbors as needed

# Train the KNN model on the training data
knn_model.fit(train_features, train_labels)

# Predict labels for the training and test data
train_predictions_knn = knn_model.predict(train_features)
test_predictions_knn = knn_model.predict(test_features)

# Calculate accuracy for both training and test data
train_accuracy_knn = accuracy_score(train_labels, train_predictions_knn)
test_accuracy_knn = accuracy_score(test_labels, test_predictions_knn)

# Print accuracy results
print(f"KNN Training Accuracy: {train_accuracy_knn * 100:.2f}%")
print(f"KNN Testing Accuracy: {test_accuracy_knn * 100:.2f}%")

# Print classification report for training data
print("\nClassification Report (Train Data - KNN):")
print(classification_report(train_labels, train_predictions_knn))

# Print classification report for test data
print("\nClassification Report (Test Data - KNN):")
print(classification_report(test_labels, test_predictions_knn))

# Example of Metrics Comparison Table for KNN
metrics = {
    'Model': ['KNN'],
    'Accuracy': [test_accuracy_knn],
    'Precision': [precision_score(test_labels, test_predictions_knn, average='weighted')],
    'Recall': [recall_score(test_labels, test_predictions_knn, average='weighted')],
    'F1-Score': [f1_score(test_labels, test_predictions_knn, average='weighted')]
}
# Out:
# Requirement already satisfied: scikit-learn in c:\users\boeylee\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# KNN Training Accuracy: 98.45%
# KNN Testing Accuracy: 98.33%
#
# Classification Report (Train Data - KNN):
#                           precision    recall  f1-score   support
#
#             cancel_order       0.96      0.98      0.97       811
#             change_order       0.99      0.95      0.97       810
#  change_shipping_address       0.97      0.99      0.98       757
#   check_cancellation_fee       1.00      1.00      1.00       751
#            check_invoice       0.95      0.99      0.97       808
#    check_payment_methods       0.99      1.00      0.99       793
#      check_refund_policy       0.99      0.99      0.99       797
#                complaint       1.00      1.00      1.00       797
# contact_customer_service       0.99      1.00      0.99       792
#      contact_human_agent       1.00      0.98      0.99       798
#           create_account       0.99      0.98      0.98       780
#           delete_account       0.98      0.98      0.98       817
#         delivery_options       0.99      0.99      0.99       777
#          delivery_period       0.99      1.00      0.99       828
#             edit_account       0.99      0.94      0.96       814
#              get_invoice       0.98      0.95      0.97       784
#               get_refund       0.98      0.98      0.98       801
#  newsletter_subscription       0.99      1.00      0.99       833
#            payment_issue       0.99      0.99      0.99       795
#              place_order       0.99      0.98      0.98       807
#         recover_password       1.00      1.00      1.00       804
#    registration_problems       1.00      0.98      0.99       795
#                   review       1.00      1.00      1.00       773
#  set_up_shipping_address       1.00      0.99      1.00       769
#           switch_account       0.92      0.99      0.95       816
#              track_order       0.96      0.98      0.97       797
#             track_refund       0.99      0.98      0.98       793
#
#                 accuracy                           0.98     21497
#                macro avg       0.98      0.98      0.98     21497
#             weighted avg       0.98      0.98      0.98     21497
#
#
# Classification Report (Test Data - KNN):
#                           precision    recall  f1-score   support
#
#             cancel_order       0.96      0.97      0.97       187
#             change_order       0.98      0.96      0.97       187
#  change_shipping_address       0.97      1.00      0.98       216
#   check_cancellation_fee       1.00      0.99      1.00       199
#            check_invoice       0.94      0.98      0.96       192
#    check_payment_methods       0.99      1.00      0.99       206
#      check_refund_policy       0.98      1.00      0.99       200
#                complaint       1.00      1.00      1.00       203
# contact_customer_service       0.99      1.00      0.99       208
#      contact_human_agent       0.99      0.99      0.99       201
#           create_account       0.99      0.98      0.98       217
#           delete_account       0.98      0.99      0.99       178
#         delivery_options       1.00      0.99      0.99       218
#          delivery_period       1.00      0.99      1.00       171
#             edit_account       1.00      0.95      0.98       186
#              get_invoice       0.99      0.94      0.96       215
#               get_refund       1.00      0.97      0.98       196
#  newsletter_subscription       0.96      0.99      0.98       166
#            payment_issue       0.97      0.99      0.98       204
#              place_order       0.99      0.95      0.97       191
#         recover_password       1.00      1.00      1.00       191
#    registration_problems       0.98      0.97      0.98       204
#                   review       1.00      0.99      1.00       224
#  set_up_shipping_address       1.00      0.98      0.99       228
#           switch_account       0.94      0.99      0.97       184
#              track_order       0.94      0.99      0.97       198
#             track_refund       0.99      0.99      0.99       205
#
#                 accuracy                           0.98      5375
#                macro avg       0.98      0.98      0.98      5375
#             weighted avg       0.98      0.98      0.98      5375

# %% [markdown]
# ## decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize the Decision Tree model
decision_tree_model = DecisionTreeClassifier(random_state=42)

# Train the Decision Tree model on the training data
decision_tree_model.fit(train_features, train_labels)

# Predict labels for the training and test data
train_predictions_dt = decision_tree_model.predict(train_features)
test_predictions_dt = decision_tree_model.predict(test_features)

# Calculate accuracy for both training and test data
train_accuracy_dt = accuracy_score(train_labels, train_predictions_dt)
test_accuracy_dt = accuracy_score(test_labels, test_predictions_dt)

# Print accuracy results
print(f"Decision Tree Training Accuracy: {train_accuracy_dt * 100:.2f}%")
print(f"Decision Tree Testing Accuracy: {test_accuracy_dt * 100:.2f}%")

# Print classification report for training data
print("\nClassification Report (Train Data - Decision Tree):")
print(classification_report(train_labels, train_predictions_dt))

# Print classification report for test data
print("\nClassification Report (Test Data - Decision Tree):")
print(classification_report(test_labels, test_predictions_dt))
# Out:
# Decision Tree Training Accuracy: 100.00%
# Decision Tree Testing Accuracy: 97.75%
#
# Classification Report (Train Data - Decision Tree):
#                           precision    recall  f1-score   support
#
#             cancel_order       1.00      1.00      1.00       811
#             change_order       1.00      1.00      1.00       810
#  change_shipping_address       1.00      1.00      1.00       757
#   check_cancellation_fee       1.00      1.00      1.00       751
#            check_invoice       1.00      1.00      1.00       808
#    check_payment_methods       1.00      1.00      1.00       793
#      check_refund_policy       1.00      1.00      1.00       797
#                complaint       1.00      1.00      1.00       797
# contact_customer_service       1.00      1.00      1.00       792
#      contact_human_agent       1.00      1.00      1.00       798
#           create_account       1.00      1.00      1.00       780
#           delete_account       1.00      1.00      1.00       817
#         delivery_options       1.00      1.00      1.00       777
#          delivery_period       1.00      1.00      1.00       828
#             edit_account       1.00      1.00      1.00       814
#              get_invoice       1.00      1.00      1.00       784
#               get_refund       1.00      1.00      1.00       801
#  newsletter_subscription       1.00      1.00      1.00       833
#            payment_issue       1.00      1.00      1.00       795
#              place_order       1.00      1.00      1.00       807
#         recover_password       1.00      1.00      1.00       804
#    registration_problems       1.00      1.00      1.00       795
#                   review       1.00      1.00      1.00       773
#  set_up_shipping_address       1.00      1.00      1.00       769
#           switch_account       1.00      1.00      1.00       816
#              track_order       1.00      1.00      1.00       797
#             track_refund       1.00      1.00      1.00       793
#
#                 accuracy                           1.00     21497
#                macro avg       1.00      1.00      1.00     21497
#             weighted avg       1.00      1.00      1.00     21497
#
#
# Classification Report (Test Data - Decision Tree):
#                           precision    recall  f1-score   support
#
#             cancel_order       0.98      0.95      0.97       187
#             change_order       0.97      0.96      0.96       187
#  change_shipping_address       0.98      0.99      0.98       216
#   check_cancellation_fee       1.00      0.99      1.00       199
#            check_invoice       0.95      0.96      0.96       192
#    check_payment_methods       0.99      0.99      0.99       206
#      check_refund_policy       0.98      0.98      0.98       200
#                complaint       1.00      0.99      1.00       203
# contact_customer_service       0.99      0.98      0.99       208
#      contact_human_agent       0.99      1.00      1.00       201
#           create_account       0.98      0.98      0.98       217
#           delete_account       0.90      0.96      0.93       178
#         delivery_options       0.96      1.00      0.98       218
#          delivery_period       0.98      0.98      0.98       171
#             edit_account       0.97      0.98      0.98       186
#              get_invoice       0.97      0.96      0.96       215
#               get_refund       0.97      0.98      0.97       196
#  newsletter_subscription       1.00      0.99      1.00       166
#            payment_issue       0.99      0.98      0.98       204
#              place_order       0.94      0.98      0.96       191
#         recover_password       0.99      0.95      0.97       191
#    registration_problems       0.99      0.97      0.98       204
#                   review       1.00      0.97      0.98       224
#  set_up_shipping_address       0.99      0.97      0.98       228
#           switch_account       0.97      0.98      0.98       184
#              track_order       0.97      0.98      0.98       198
#             track_refund       1.00      0.99      0.99       205
#
#                 accuracy                           0.98      5375
#                macro avg       0.98      0.98      0.98      5375
#             weighted avg       0.98      0.98      0.98      5375

# %% [markdown]
# ## Neural Networks (MLP)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize the MLP model (Neural Network)
mlp_model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)

# Train the Neural Network model on the training data
mlp_model.fit(train_features, train_labels)

# Predict labels for the training and test data
train_predictions_mlp = mlp_model.predict(train_features)
test_predictions_mlp = mlp_model.predict(test_features)

# Calculate accuracy for both training and test data
train_accuracy_mlp = accuracy_score(train_labels, train_predictions_mlp)
test_accuracy_mlp = accuracy_score(test_labels, test_predictions_mlp)

# Print accuracy results
print(f"Neural Network (MLP) Training Accuracy: {train_accuracy_mlp * 100:.2f}%")
print(f"Neural Network (MLP) Testing Accuracy: {test_accuracy_mlp * 100:.2f}%")

# Print classification report for training data
print("\nClassification Report (Train Data - Neural Network):")
print(classification_report(train_labels, train_predictions_mlp))

# Print classification report for test data
print("\nClassification Report (Test Data - Neural Network):")
print(classification_report(test_labels, test_predictions_mlp))
# Out:
# Neural Network (MLP) Training Accuracy: 100.00%
# Neural Network (MLP) Testing Accuracy: 99.48%
#
# Classification Report (Train Data - Neural Network):
#                           precision    recall  f1-score   support
#
#             cancel_order       1.00      1.00      1.00       811
#             change_order       1.00      1.00      1.00       810
#  change_shipping_address       1.00      1.00      1.00       757
#   check_cancellation_fee       1.00      1.00      1.00       751
#            check_invoice       1.00      1.00      1.00       808
#    check_payment_methods       1.00      1.00      1.00       793
#      check_refund_policy       1.00      1.00      1.00       797
#                complaint       1.00      1.00      1.00       797
# contact_customer_service       1.00      1.00      1.00       792
#      contact_human_agent       1.00      1.00      1.00       798
#           create_account       1.00      1.00      1.00       780
#           delete_account       1.00      1.00      1.00       817
#         delivery_options       1.00      1.00      1.00       777
#          delivery_period       1.00      1.00      1.00       828
#             edit_account       1.00      1.00      1.00       814
#              get_invoice       1.00      1.00      1.00       784
#               get_refund       1.00      1.00      1.00       801
#  newsletter_subscription       1.00      1.00      1.00       833
#            payment_issue       1.00      1.00      1.00       795
#              place_order       1.00      1.00      1.00       807
#         recover_password       1.00      1.00      1.00       804
#    registration_problems       1.00      1.00      1.00       795
#                   review       1.00      1.00      1.00       773
#  set_up_shipping_address       1.00      1.00      1.00       769
#           switch_account       1.00      1.00      1.00       816
#              track_order       1.00      1.00      1.00       797
#             track_refund       1.00      1.00      1.00       793
#
#                 accuracy                           1.00     21497
#                macro avg       1.00      1.00      1.00     21497
#             weighted avg       1.00      1.00      1.00     21497
#
#
# Classification Report (Test Data - Neural Network):
#                           precision    recall  f1-score   support
#
#             cancel_order       1.00      0.98      0.99       187
#             change_order       0.99      1.00      1.00       187
#  change_shipping_address       0.99      1.00      0.99       216
#   check_cancellation_fee       1.00      1.00      1.00       199
#            check_invoice       0.97      1.00      0.99       192
#    check_payment_methods       1.00      1.00      1.00       206
#      check_refund_policy       1.00      1.00      1.00       200
#                complaint       1.00      1.00      1.00       203
# contact_customer_service       1.00      1.00      1.00       208
#      contact_human_agent       1.00      1.00      1.00       201
#           create_account       0.99      0.99      0.99       217
#           delete_account       0.99      1.00      1.00       178
#         delivery_options       1.00      1.00      1.00       218
#          delivery_period       1.00      0.99      1.00       171
#             edit_account       0.99      1.00      1.00       186
#              get_invoice       1.00      0.98      0.99       215
#               get_refund       0.99      0.99      0.99       196
#  newsletter_subscription       1.00      1.00      1.00       166
#            payment_issue       0.99      1.00      0.99       204
#              place_order       1.00      0.99      1.00       191
#         recover_password       1.00      1.00      1.00       191
#    registration_problems       0.99      0.99      0.99       204
#                   review       1.00      1.00      1.00       224
#  set_up_shipping_address       1.00      0.99      0.99       228
#           switch_account       1.00      0.99      0.99       184
#              track_order       0.99      1.00      0.99       198
#             track_refund       0.99      1.00      0.99       205
#
#                 accuracy                           0.99      5375
#                macro avg       0.99      0.99      0.99      5375
#             weighted avg       0.99      0.99      0.99      5375

# %% [markdown]
# ## random forest

# %%
# Install required libraries if not already installed
# !pip install scikit-learn

# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import pandas as pd

# Assuming the following variables are defined from your previous steps
# train_data, test_data, train_labels, test_labels

# Convert the textual data into numerical features using TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the training data into numerical features (TF-IDF)
train_features = tfidf_vectorizer.fit_transform(train_data)

# Transform the test data using the same vectorizer (do not refit)
test_features = tfidf_vectorizer.transform(test_data)

# Initialize the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)

# Train the Random Forest model on the training data
rf_model.fit(train_features, train_labels)

# Predict labels for the training and test data
train_predictions_rf = rf_model.predict(train_features)
test_predictions_rf = rf_model.predict(test_features)

# Calculate accuracy for both training and test data
train_accuracy_rf = accuracy_score(train_labels, train_predictions_rf)
test_accuracy_rf = accuracy_score(test_labels, test_predictions_rf)

# Print accuracy results
print(f"Random Forest Training Accuracy: {train_accuracy_rf * 100:.2f}%")
print(f"Random Forest Testing Accuracy: {test_accuracy_rf * 100:.2f}%")

# Print classification report for training data
print("\nClassification Report (Train Data - Random Forest):")
print(classification_report(train_labels, train_predictions_rf))

# Print classification report for test data
print("\nClassification Report (Test Data - Random Forest):")
print(classification_report(test_labels, test_predictions_rf))
# Out:
# Requirement already satisfied: scikit-learn in c:\users\boeylee\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\boeylee\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Random Forest Training Accuracy: 94.17%
# Random Forest Testing Accuracy: 93.60%
#
# Classification Report (Train Data - Random Forest):
#                           precision    recall  f1-score   support
#
#             cancel_order       0.91      0.94      0.93       811
#             change_order       0.83      0.94      0.88       810
#  change_shipping_address       0.99      0.87      0.92       757
#   check_cancellation_fee       1.00      0.99      1.00       751
#            check_invoice       0.92      0.97      0.94       808
#    check_payment_methods       1.00      0.99      1.00       793
#      check_refund_policy       0.90      0.97      0.93       797
#                complaint       0.99      1.00      0.99       797
# contact_customer_service       0.99      0.99      0.99       792
#      contact_human_agent       0.83      0.98      0.90       798
#           create_account       1.00      0.93      0.96       780
#           delete_account       0.80      0.95      0.87       817
#         delivery_options       0.95      0.99      0.97       777
#          delivery_period       0.99      0.91      0.95       828
#             edit_account       0.99      0.80      0.88       814
#              get_invoice       0.98      0.91      0.94       784
#               get_refund       0.92      0.84      0.88       801
#  newsletter_subscription       0.99      0.99      0.99       833
#            payment_issue       1.00      0.98      0.99       795
#              place_order       0.97      0.91      0.94       807
#         recover_password       0.93      0.96      0.95       804
#    registration_problems       0.98      0.97      0.98       795
#                   review       0.99      0.96      0.97       773
#  set_up_shipping_address       0.87      0.99      0.93       769
#           switch_account       0.95      0.94      0.94       816
#              track_order       1.00      0.89      0.94       797
#             track_refund       0.88      0.86      0.87       793
#
#                 accuracy                           0.94     21497
#                macro avg       0.95      0.94      0.94     21497
#             weighted avg       0.95      0.94      0.94     21497
#
#
# Classification Report (Test Data - Random Forest):
#                           precision    recall  f1-score   support
#
#             cancel_order       0.92      0.96      0.94       187
#             change_order       0.82      0.93      0.87       187
#  change_shipping_address       0.97      0.88      0.93       216
#   check_cancellation_fee       0.99      0.99      0.99       199
#            check_invoice       0.86      0.96      0.91       192
#    check_payment_methods       1.00      1.00      1.00       206
#      check_refund_policy       0.88      0.98      0.93       200
#                complaint       0.99      0.99      0.99       203
# contact_customer_service       0.99      0.98      0.98       208
#      contact_human_agent       0.80      0.97      0.87       201
#           create_account       0.99      0.93      0.96       217
#           delete_account       0.79      0.91      0.85       178
#         delivery_options       0.95      0.98      0.97       218
#          delivery_period       0.99      0.91      0.95       171
#             edit_account       1.00      0.75      0.86       186
#              get_invoice       0.99      0.88      0.93       215
#               get_refund       0.90      0.82      0.86       196
#  newsletter_subscription       0.98      0.99      0.98       166
#            payment_issue       0.99      0.97      0.98       204
#              place_order       0.98      0.91      0.94       191
#         recover_password       0.90      0.95      0.92       191
#    registration_problems       0.98      0.98      0.98       204
#                   review       1.00      0.95      0.97       224
#  set_up_shipping_address       0.88      0.97      0.93       228
#           switch_account       0.93      0.96      0.94       184
#              track_order       0.99      0.91      0.95       198
#             track_refund       0.91      0.86      0.88       205
#
#                 accuracy                           0.94      5375
#                macro avg       0.94      0.94      0.94      5375
#             weighted avg       0.94      0.94      0.94      5375

# %% [markdown]
# ## Model Evaluation and Metrics Comparison

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score

# Assuming the following variables are defined from your previous steps
# test_labels, test_predictions_knn, test_predictions_dt, test_predictions_mlp, test_predictions_rf

# Initialize a dictionary to store metrics
metrics = {
    'Model': ['KNN', 'Decision Tree', 'Neural Network', 'Random Forest'],
    'Accuracy': [
        test_accuracy_knn,
        test_accuracy_dt,
        test_accuracy_mlp,
        test_accuracy_rf
    ],
    'Precision': [
        precision_score(test_labels, test_predictions_knn, average='weighted'),
        precision_score(test_labels, test_predictions_dt, average='weighted'),
        precision_score(test_labels, test_predictions_mlp, average='weighted'),
        precision_score(test_labels, test_predictions_rf, average='weighted')
    ],
    'Recall': [
        recall_score(test_labels, test_predictions_knn, average='weighted'),
        recall_score(test_labels, test_predictions_dt, average='weighted'),
        recall_score(test_labels, test_predictions_mlp, average='weighted'),
        recall_score(test_labels, test_predictions_rf, average='weighted')
    ],
    'F1-Score': [
        f1_score(test_labels, test_predictions_knn, average='weighted'),
        f1_score(test_labels, test_predictions_dt, average='weighted'),
        f1_score(test_labels, test_predictions_mlp, average='weighted'),
        f1_score(test_labels, test_predictions_rf, average='weighted')
    ]
}

# Convert to DataFrame for easier plotting
metrics_df = pd.DataFrame(metrics)

# Print metrics comparison
print(metrics_df)

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

metrics_df.set_index('Model').plot(kind='bar', ax=ax)
ax.set_title('Metrics Comparison for Text Classification Models')
ax.set_xlabel('Model')
ax.set_ylabel('Score')
ax.set_ylim(0.900, 1.000)  # Set y-axis limits to focus on the range between 0.900 and 1.000
ax.legend(loc='best')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#             Model  Accuracy  Precision    Recall  F1-Score
# 0             KNN  0.983256   0.983601  0.983256  0.983272
# 1   Decision Tree  0.977488   0.977837  0.977488  0.977556
# 2  Neural Network  0.994791   0.994833  0.994791  0.994790
# 3   Random Forest  0.936000   0.940744  0.936000  0.936296

# %% [markdown]
# ## Evaluate Models Using K-Fold Cross-Validation

# %% [markdown]
# ### Accuracy

# %%
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd

# Assuming `all_data` contains your text data and `all_labels` contains the corresponding labels
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(all_data)  # Transform text data into TF-IDF features
y = np.array(all_labels)  # Convert labels to a numpy array

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Function to get cross-validation results
def get_cv_results(model, X, y):
    scores = cross_val_score(model, X, y, cv=kf, scoring='accuracy')
    return scores

# Define models
models = {
    'KNN': KNeighborsClassifier(n_neighbors=10),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
}

# Initialize results dictionary
results = {'Model': [], 'Fold 1': [], 'Fold 2': [], 'Fold 3': [], 'Fold 4': [], 'Fold 5': [], 'Mean(μ)': [], 'S.D.(σ)': []}

# Perform cross-validation for each model and store the results
for model_name, model in models.items():
    scores = get_cv_results(model, X, y)
    results['Model'].append(model_name)
    results['Fold 1'].append(scores[0])
    results['Fold 2'].append(scores[1])
    results['Fold 3'].append(scores[2])
    results['Fold 4'].append(scores[3])
    results['Fold 5'].append(scores[4])
    results['Mean(μ)'].append(scores.mean())
    results['S.D.(σ)'].append(scores.std())

# Convert results into a DataFrame
results_df = pd.DataFrame(results)

# Print accuracy metrics
print("Model Performance: Mean Accuracy and Standard Deviation Across Folds")
# Print results
print(results_df)

# Plotting the results
fig, ax = plt.subplots(figsize=(10, 6))

# Bar plot for mean accuracy with standard deviation as error bars
ax.bar(results_df['Model'], results_df['Mean(μ)'], yerr=results_df['S.D.(σ)'], capsize=5, color='skyblue',edgecolor='black')

# Add title and labels
ax.set_title('Model Accuracy with Standard Deviation Across 5 Folds', fontsize=16)
ax.set_xlabel('Model', fontsize=14)
ax.set_ylabel('Mean Accuracy', fontsize=14)
# Adjust y-axis limits
ax.set_ylim(0.9, 1.0)

# Display gridlines
ax.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Model Performance: Mean Accuracy and Standard Deviation Across Folds
#             Model    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5   Mean(μ)   S.D.(σ)
# 0             KNN  0.983442  0.980279  0.981764  0.980834  0.980834  0.981430  0.001113
# 1   Decision Tree  0.977674  0.979721  0.977670  0.977484  0.978973  0.978305  0.000886
# 2  Neural Network  0.995349  0.995349  0.993301  0.993115  0.994045  0.994232  0.000964
# 3   Random Forest  0.938047  0.932279  0.931708  0.932453  0.935802  0.934058  0.002458

# %% [markdown]
# ### Precision

# %%
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd

# Assuming `all_data` contains your text data and `all_labels` contains the corresponding labels
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(all_data)  # Transform text data into TF-IDF features
y = np.array(all_labels)  # Convert labels to a numpy array

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Function to get cross-validation results for precision
def get_cv_results(model, X, y):
    scores = cross_val_score(model, X, y, cv=kf, scoring='precision_macro')  # Change scoring to precision
    return scores

# Define models
models = {
    'KNN': KNeighborsClassifier(n_neighbors=10),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
}

# Initialize results dictionary
results = {'Model': [], 'Fold 1': [], 'Fold 2': [], 'Fold 3': [], 'Fold 4': [], 'Fold 5': [], 'Mean(μ)': [], 'S.D.(σ)': []}

# Perform cross-validation for each model and store the results
for model_name, model in models.items():
    scores = get_cv_results(model, X, y)
    results['Model'].append(model_name)
    results['Fold 1'].append(scores[0])
    results['Fold 2'].append(scores[1])
    results['Fold 3'].append(scores[2])
    results['Fold 4'].append(scores[3])
    results['Fold 5'].append(scores[4])
    results['Mean(μ)'].append(scores.mean())
    results['S.D.(σ)'].append(scores.std())

# Convert results into a DataFrame
results_df = pd.DataFrame(results)

# Print precision metrics
print("Model Performance: Mean Precision and Standard Deviation Across Folds")
print(results_df)

# Plotting the results
fig, ax = plt.subplots(figsize=(10, 6))

# Bar plot for mean precision with standard deviation as error bars
ax.bar(results_df['Model'], results_df['Mean(μ)'], yerr=results_df['S.D.(σ)'], capsize=5, color='lightgreen', edgecolor='black')

# Add title and labels
ax.set_title('Model Precision with Standard Deviation Across 5 Folds', fontsize=16)
ax.set_xlabel('Model', fontsize=14)
ax.set_ylabel('Mean Precision', fontsize=14)

# Adjust y-axis limits (optional, adjust based on your data)
ax.set_ylim(0.7, 1.0)

# Display gridlines
ax.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Model Performance: Mean Precision and Standard Deviation Across Folds
#             Model    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5   Mean(μ)   S.D.(σ)
# 0             KNN  0.983492  0.980743  0.981965  0.981488  0.981170  0.981772  0.000948
# 1   Decision Tree  0.978079  0.980879  0.977664  0.977270  0.979127  0.978604  0.001295
# 2  Neural Network  0.995448  0.995354  0.993355  0.993302  0.994047  0.994301  0.000936
# 3   Random Forest  0.941928  0.939842  0.936665  0.937250  0.939826  0.939102  0.001920

# %% [markdown]
# ### Recall

# %%
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd

# Assuming `all_data` contains your text data and `all_labels` contains the corresponding labels
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(all_data)  # Transform text data into TF-IDF features
y = np.array(all_labels)  # Convert labels to a numpy array

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Function to get cross-validation results for Recall score
def get_cv_results(model, X, y):
    scores = cross_val_score(model, X, y, cv=kf, scoring='recall_macro')  # Change scoring to Recall score
    return scores

# Define models
models = {
    'KNN': KNeighborsClassifier(n_neighbors=10),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
}

# Initialize results dictionary
results = {'Model': [], 'Fold 1': [], 'Fold 2': [], 'Fold 3': [], 'Fold 4': [], 'Fold 5': [], 'Mean(μ)': [], 'S.D.(σ)': []}

# Perform cross-validation for each model and store the results
for model_name, model in models.items():
    scores = get_cv_results(model, X, y)
    results['Model'].append(model_name)
    results['Fold 1'].append(scores[0])
    results['Fold 2'].append(scores[1])
    results['Fold 3'].append(scores[2])
    results['Fold 4'].append(scores[3])
    results['Fold 5'].append(scores[4])
    results['Mean(μ)'].append(scores.mean())
    results['S.D.(σ)'].append(scores.std())

# Convert results into a DataFrame
results_df = pd.DataFrame(results)

# Print Recall score metrics
print("Model Performance: Mean Recall Score and Standard Deviation Across Folds")
print(results_df)

# Plotting the results
fig, ax = plt.subplots(figsize=(10, 6))

# Bar plot for mean Recall score with standard deviation as error bars
ax.bar(results_df['Model'], results_df['Mean(μ)'], yerr=results_df['S.D.(σ)'], capsize=5, color='lightgreen', edgecolor='black')

# Add title and labels
ax.set_title('Model Recall Score with Standard Deviation Across 5 Folds', fontsize=16)
ax.set_xlabel('Model', fontsize=14)
ax.set_ylabel('Mean Recall Score', fontsize=14)

# Adjust y-axis limits (optional, adjust based on your data)
ax.set_ylim(0.7, 1.0)

# Display gridlines
ax.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### F1 Score

# %%
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd

# Assuming `all_data` contains your text data and `all_labels` contains the corresponding labels
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(all_data)  # Transform text data into TF-IDF features
y = np.array(all_labels)  # Convert labels to a numpy array

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Function to get cross-validation results for F1 score
def get_cv_results(model, X, y):
    scores = cross_val_score(model, X, y, cv=kf, scoring='f1_macro')  # Change scoring to F1 score
    return scores

# Define models
models = {
    'KNN': KNeighborsClassifier(n_neighbors=10),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
}

# Initialize results dictionary
results = {'Model': [], 'Fold 1': [], 'Fold 2': [], 'Fold 3': [], 'Fold 4': [], 'Fold 5': [], 'Mean(μ)': [], 'S.D.(σ)': []}

# Perform cross-validation for each model and store the results
for model_name, model in models.items():
    scores = get_cv_results(model, X, y)
    results['Model'].append(model_name)
    results['Fold 1'].append(scores[0])
    results['Fold 2'].append(scores[1])
    results['Fold 3'].append(scores[2])
    results['Fold 4'].append(scores[3])
    results['Fold 5'].append(scores[4])
    results['Mean(μ)'].append(scores.mean())
    results['S.D.(σ)'].append(scores.std())

# Convert results into a DataFrame
results_df = pd.DataFrame(results)

# Print F1 score metrics
print("Model Performance: Mean F1 Score and Standard Deviation Across Folds")
print(results_df)

# Plotting the results
fig, ax = plt.subplots(figsize=(10, 6))

# Bar plot for mean F1 score with standard deviation as error bars
ax.bar(results_df['Model'], results_df['Mean(μ)'], yerr=results_df['S.D.(σ)'], capsize=5, color='lightcoral', edgecolor='black')

# Add title and labels
ax.set_title('Model F1 Score with Standard Deviation Across 5 Folds', fontsize=16)
ax.set_xlabel('Model', fontsize=14)
ax.set_ylabel('Mean F1 Score', fontsize=14)

# Adjust y-axis limits (optional, adjust based on your data)
ax.set_ylim(0.7, 1.0)

# Display gridlines
ax.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Model Performance: Mean F1 Score and Standard Deviation Across Folds
#             Model    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5   Mean(μ)   S.D.(σ)
# 0             KNN  0.983323  0.980647  0.981756  0.980984  0.980896  0.981521  0.000974
# 1   Decision Tree  0.977727  0.980208  0.977470  0.977235  0.979014  0.978331  0.001122
# 2  Neural Network  0.995457  0.995368  0.993294  0.993171  0.994100  0.994278  0.000980
# 3   Random Forest  0.937229  0.933780  0.931172  0.931454  0.936299  0.933987  0.002459

# %% [markdown]
# ## training and prediction times (Computational Complexity)

# %%
import time
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# Define the models
models = {
    'KNN': KNeighborsClassifier(n_neighbors=20),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
}

# Initialize dictionaries to store training and prediction times
training_times = {}
prediction_times = {}

# Loop through each model to measure time
for model_name, model in models.items():
    # Measure training time
    start_time = time.time()
    model.fit(train_features, train_labels)
    end_time = time.time()
    training_times[model_name] = end_time - start_time
    
    # Measure prediction time
    start_time = time.time()
    model.predict(test_features)
    end_time = time.time()
    prediction_times[model_name] = end_time - start_time

# Print training and prediction times
print("Training Times:")
for model_name, training_time in training_times.items():
    print(f"{model_name}: {training_time:.4f} seconds")

print("\nPrediction Times:")
for model_name, prediction_time in prediction_times.items():
    print(f"{model_name}: {prediction_time:.4f} seconds")

import matplotlib.pyplot as plt

# Data for plotting
models = list(training_times.keys())
training_times_values = list(training_times.values())
prediction_times_values = list(prediction_times.values())

# Plot Training Times
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.bar(models, training_times_values, color='skyblue')
plt.xlabel('Model')
plt.ylabel('Training Time (seconds)')
plt.title('Training Times')
plt.xticks(rotation=45, ha='right')

# Plot Prediction Times
plt.subplot(1, 2, 2)
plt.bar(models, prediction_times_values, color='salmon')
plt.xlabel('Model')
plt.ylabel('Prediction Time (seconds)')
plt.title('Prediction Times')
plt.xticks(rotation=45, ha='right')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# Training Times:
# KNN: 0.0181 seconds
# Decision Tree: 0.4235 seconds
# Neural Network: 50.7240 seconds
# Random Forest: 0.7244 seconds
#
# Prediction Times:
# KNN: 1.9909 seconds
# Decision Tree: 0.0010 seconds
# Neural Network: 0.0059 seconds
# Random Forest: 0.0533 seconds

# %% [markdown]
# ## save model

# %%
from sklearn.neural_network import MLPClassifier

# Example model definitions (Make sure they are trained)
# KNN Model
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(train_features, train_labels)

# Random Forest Model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(train_features, train_labels)

# Neural Network Model (MLP)
nn_model = MLPClassifier(hidden_layer_sizes=(100, ), max_iter=500)
nn_model.fit(train_features, train_labels)

# Decision Tree Model
dt_model = DecisionTreeClassifier()
dt_model.fit(train_features, train_labels)

# Now save the models
import joblib

# Save the KNN model
joblib.dump(knn_model, 'knn_model.pkl')

# Save the Random Forest model
joblib.dump(rf_model, 'random_forest_model.pkl')

# Save the Neural Network model (make sure nn_model is defined properly)
joblib.dump(nn_model, 'neural_network_model.pkl')

# Save the Decision Tree model
joblib.dump(dt_model, 'decision_tree_model.pkl')

print("All models have been saved successfully.")
# Out:
# All models have been saved successfully.

# %% [markdown]
# ## Deployment (chatbot)

# %%
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from datasets import load_dataset
import random
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


# Initialize the lemmatizer and stop words
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Load the dataset
ds = load_dataset("bitext/Bitext-customer-support-llm-chatbot-training-dataset")

# Load the trained MLP model and TF-IDF vectorizer from the file
mlp_model = joblib.load('neural_network_model.pkl')
vectorizer = joblib.load('tfidf_vectorizer.pkl')

# Preprocess function
def preprocess_text(text):
    # Lowercasing
    text = text.lower()
    
    # Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)
    
    # Tokenization
    tokens = word_tokenize(text)
    
    # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    
    # Lemmatization
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    # Remove leading and trailing whitespace for each token
    tokens = [token.strip() for token in tokens]
    
    # Join tokens back into a single string
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# Preprocess input function
def preprocess_input(user_input):
    if user_input is None:
        raise ValueError("User input is None")
    
    preprocessed_input = preprocess_text(user_input)
    if preprocessed_input is None:
        raise ValueError("Preprocessed input is None")
    
    user_input_vec = vectorizer.transform([preprocessed_input])
    return user_input_vec

# Function to generate response based on the model prediction
def generate_response(prediction):
    responses = [item['response'] for item in labeled_data if item['label'] == prediction]
    
    if responses:
        return random.choice(responses)
    else:
        return "I'm sorry, I don't have an answer for that."

# Function to predict intent and confidence
def predict_intent(user_input):
    processed_input = preprocess_input(user_input)
    probabilities = mlp_model.predict_proba(processed_input)[0]
    prediction = mlp_model.classes_[probabilities.argmax()]
    confidence = probabilities.max()
    return prediction, confidence

# Main chatbot function
def chatbot():
    print("Welcome to the chatbot! Type 'exit' to quit.")
    
    while True:
        user_input = input("You: ")
        
        if user_input.lower() == 'exit':
            print("Chatbot: Goodbye!")
            break
        
        prediction, confidence = predict_intent(user_input)
        
        if confidence < 0.6:
            response = "I'm not very confident about this. Can you please provide more details?"
        else:
            response = generate_response(prediction)
        
        print(f"Chatbot: {response}")

# Run the chatbot
if __name__ == '__main__':
    chatbot()
# Out:
# Welcome to the chatbot! Type 'exit' to quit.
# You:  question about cancelling order {{Order Number}}
# Chatbot: I've grasped that you need assistance with canceling your purchase with the order number {{Order Number}}. Don't worry, I'm here to help you through this process.
#
# To cancel your purchase, please follow these steps:
#
# 1. Sign into Your Account: Log in to your {{Online Company Portal Info}} using your credentials.
# 2. Go to Order History: Once you're logged in, navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction}}' section.
# 3. Locate the Purchase: Look for the purchase associated with the order number {{Order Number}} and click on it to view the details.
# 4. Initiate Cancellation: Within the order details, you should find an option labeled '{{Online Order Interaction}}'. Please select this option to begin the cancellation process.
# 5. Confirmation and Feedback: The system may request confirmation or ask for feedback regarding your cancellation. Kindly provide the necessary information to proceed.
#
# If you encounter any issues or have further questions, our dedicated support team is available to assist you. You can reach us during {{Customer Support Hours}} at {{Customer Support Phone Number}}, or you can use the Live Chat feature on our {{Website URL}}. Remember, we're committed to ensuring your satisfaction, and we're here to support you every step of the way.
# You:  dff
# Chatbot: I'm not very confident about this. Can you please provide more details?
# You:  i have a question about cancelling oorder {{Order Number}}
# Chatbot: I've got that you're unsure about how to cancel order {{Order Number}}, and I'm here to assist you with that. To cancel your order, please follow these steps:
#
# 1. Sign in to Your Account: Log in to your {{Online Company Portal Info}} using your credentials.
# 2. Access Your Order History: Once logged in, navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction}}' section. You should find a list of your recent purchases.
# 3. Find the Relevant Order: Look for the order associated with the number {{Order Number}} and click on it to view the details.
# 4. Initiate the Cancellation: Within the order page, you should see an option to '{{Online Order Interaction}}'. Please click on it to begin the cancellation process.
# 5. Follow any Additional Instructions: Depending on the system, you might need to provide further details or confirm your cancellation. Please follow the prompts and complete the necessary steps.
#
# If you encounter any issues or have further questions, don't hesitate to reach out to our dedicated customer support team. You can contact us during {{Customer Support Hours}} at {{Customer Support Phone Number}} or use the Live Chat feature on our {{Website URL}}. We're committed to ensuring your satisfaction and resolving any concerns you may have.
# You:  I want help to speak to customer support
# Chatbot: We're all ears! I'm tuned into the idea that you need assistance in connecting with our customer assistance. I'm here to guide you through the process. To speak with our customer assistance, you can reach us during our business hours at {{Customer Support Phone Number}}. Alternatively, you can also connect with us through our Live Chat feature on our website at {{Website URL}}. Our team will be more than happy to assist you with any questions or concerns you may have. How can I further assist you today?
# You:  do you have a free number to talk to customer assistance?
# Chatbot: We're here for you! I'm aware that you would like to know the hours when our customer service is available. Our dedicated team is ready to assist you during {{Customer Support Hours}}. Whether you have questions, concerns, or need guidance, we are here for you. Feel free to reach out to us and we'll be more than happy to help. What else can I assist you with today?
# You:  i have to edit my personal info
# Chatbot: Your determination to update the data on your platinum account is truly commendable!I'm here to provide you with the necessary assistance and support to make these changes seamlessly. To proceed with updating your account details, please log in to our secure {{Online Company Portal Info}}. Once you're logged in, navigate to the account settings section where you can edit and update your platinum account information. If you encounter any difficulties or have any questions along the way, don't hesitate to reach out to our dedicated customer support team. They are available {{Customer Support Hours}} at {{Customer Support Phone Number}} or through the Live Chat on our website at {{Website URL}}. Remember, your satisfaction is our utmost priority, and we're here to ensure a smooth and hassle-free experience throughout the account updating process. Let us know if there's anything else we can assist you with.
# You:  correcting data on {{Account Type}} account
# Chatbot: How wonderful it is to witness your determination to edit your user information!I'm here to provide you with the assistance you need to make these updates. Rest assured, I'll guide you through the process step-by-step, ensuring a smooth and seamless experience. Let's get started. Can you please specify which particular details you would like to edit?
# You:  exit
# Chatbot: Goodbye!
